# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('all_props_new.csv')

# %%
df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Ba      137.33         268.0               0.89             5.212
# 1       Ba      137.33         268.0               0.89             5.212
# 2       Ba      137.33         268.0               0.89             5.212
# 3       Ba      137.33         268.0               0.89             5.212
# 4       Ca       40.08         231.0               1.00             6.113
# ..     ...         ...           ...                ...               ...
# 159     Se       78.97         190.0               2.55             9.752
# 160      S       32.07         180.0               2.58            10.360
# 161     Te      127.60         206.0               2.10             9.010
# 162     Zr       91.22         186.0               1.33             6.634
# 163     Zr       91.22         186.0               1.33             6.634
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 0                 NaN           272.0          12.687328       38.061983
# 1                 NaN           272.0           8.222697        8.855212
# 2                 NaN           272.0          11.320007       16.980010
# 3                 NaN           272.0           9.283639       11.140367
# 4                 NaN           160.8          10.971699       29.257864
# ..                ...             ...                ...             ...
# 159             2.021            28.9           2.714427        5.428853
# 160             2.077            19.4           2.662137        5.324275
# 161             1.971            38.0           2.714538        5.429076
# 162             0.426           112.0          15.521209       23.281813
# 163             0.426           112.0          17.876717       35.753433
#
#       ZnSites  CounterIonSites  results_per_counter_ion  \
# 0    0.333333         0.333333                 0.038062
# 1    0.928571         0.928571                 0.008855
# 2    0.666667         0.666667                 0.016980
# 3    0.833333         0.833333                 0.011140
# 4    0.375000         0.375000                 0.029258
# ..        ...              ...                      ...
# 159  0.500000         0.500000                 0.005429
# 160  0.500000         0.500000                 0.005324
# 161  0.500000         0.500000                 0.005429
# 162  0.666667         0.666667                 0.023282
# 163  0.500000         0.500000                 0.035753
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 0                 0.000290  0.290050     I4/mmm               139
# 1                 0.000506  0.505798      Fm-3c               226
# 2                 0.000435  0.434662       C2/c                15
# 3                 0.000469  0.469207       Cmcm                63
# 4                 0.000372  0.372091     I4/mcm               140
# ..                     ...       ...        ...               ...
# 159               0.000119  0.119452      F-43m               216
# 160               0.000136  0.136220       P3m1               156
# 161               0.000095  0.095148      F-43m               216
# 162               0.000935  0.935449      Fd-3m               227
# 163               0.000974  0.974113      Pm-3m               221
#
#      Total Sites Reduced Formula
# 0              3           Ba2Zn
# 1             28          BaZn13
# 2              6           BaZn2
# 3             12           BaZn5
# 4             16          Ca5Zn3
# ..           ...             ...
# 159            2            ZnSe
# 160           56             ZnS
# 161            6            ZnTe
# 162            6           ZrZn2
# 163            2            ZrZn
#
# [164 rows x 18 columns]

# %%
element = 'I'

# %%
grouped_df = df.groupby('Symbol')
oxy_group = pd.DataFrame()
for symbol, group in grouped_df:
    # print(f"Category: {symbol}")
    # print(group['Result'].max())
    # print(group['Result'].min())
    if symbol == element:
        # print(group['Result'])
        # print('---------------------')
        # print((group['Result'].max() - group['Result'].min())/group['Result'].mean() * 100)
        # print(group)
        oxy_group  = group
    # if(symbol == 'Al'):
    #     print(group)
    # print("\n")

oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 148      I    126.9045         198.0               2.66            10.451
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 148             3.059            32.9           1.142475        3.427424
#
#       ZnSites  CounterIonSites  results_per_counter_ion  \
# 148  0.333333         0.666667                 0.001714
#
#      res_per_volm_per_site   Result SpaceGroup  SpaceGroupNumber  Total Sites  \
# 148               0.000028  0.02831       C2/c                15           48
#
#     Reduced Formula
# 148            ZnI2

# %%
res = pd.read_csv('analysis_results.csv')

# %%
res = res[res['Symbol'] == element]

res
# Out:
#    Symbol Structure  Total Sites  Zn Sites  Counter Ion Sites  Diff Energy  \
# 43     La  La2 Zn17           19      17.0               17.0     0.255115
# 44     La  La6 Zn44           50      44.0               44.0     0.690247
# 45     La  La2 Zn22           24      22.0               22.0     0.304328
# 46     La  La2 Zn26           28      26.0               26.0     0.352609
# 47     La   La2 Zn4            6       4.0                4.0     0.090355
# 48     La   La2 Zn8           10       8.0                8.0     0.133919
# 49     La   La1 Zn1            2       1.0                1.0     0.034603
#
#     Diff per Total Sites  Diff per Zn Sites  Diff per Counter Ion Sites  \
# 43              0.013427           0.015007                    0.015007
# 44              0.013805           0.015687                    0.015687
# 45              0.012680           0.013833                    0.013833
# 46              0.012593           0.013562                    0.013562
# 47              0.015059           0.022589                    0.022589
# 48              0.013392           0.016740                    0.016740
# 49              0.017301           0.034603                    0.034603
#
#    Composition
# 43    La2 Zn17
# 44    La6 Zn44
# 45    La2 Zn22
# 46    La2 Zn26
# 47     La2 Zn4
# 48     La2 Zn8
# 49     La1 Zn1

# %%
oxy_group
# Out:
#    Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 43     La    138.9055         240.0                1.1             5.577
# 44     La    138.9055         240.0                1.1             5.577
# 45     La    138.9055         240.0                1.1             5.577
# 46     La    138.9055         240.0                1.1             5.577
# 47     La    138.9055         240.0                1.1             5.577
# 48     La    138.9055         240.0                1.1             5.577
# 49     La    138.9055         240.0                1.1             5.577
#
#     ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 43               0.5           215.0          13.427125       15.006787
# 44               0.5           215.0          13.804948       15.687441
# 45               0.5           215.0          12.680316       13.833072
# 46               0.5           215.0          12.593184       13.561891
# 47               0.5           215.0          15.059244       22.588865
# 48               0.5           215.0          13.391909       16.739886
# 49               0.5           215.0          17.301347       34.602694
#
#      ZnSites  CounterIonSites  results_per_counter_ion  res_per_volm_per_site  \
# 43  0.894737         0.894737                 0.015007               0.000824
# 44  0.880000         0.880000                 0.015687               0.000826
# 45  0.916667         0.916667                 0.013833               0.000805
# 46  0.928571         0.928571                 0.013562               0.000804
# 47  0.666667         0.666667                 0.022589               0.000681
# 48  0.800000         0.800000                 0.016740               0.000691
# 49  0.500000         0.500000                 0.034603               0.000653
#
#       Result SpaceGroup  SpaceGroupNumber  Total Sites Reduced Formula
# 43  0.823572       R-3m               166           19         La2Zn17
# 44  0.826423       C2/c                15           50         La3Zn22
# 45  0.804664       C2/m                12           24          LaZn11
# 46  0.804123      Fm-3c               226           28          LaZn13
# 47  0.680786       Imma                74            6           LaZn2
# 48  0.691460       Cmcm                63           10           LaZn4
# 49  0.652914      Pm-3m               221            2            LaZn

# %%
merged_df = pd.merge(res, oxy_group, left_index=True, right_index=True)
# merged_df.sort_values(by='Result',inplace=True, ascending=False)
# merged_df['SpaceGroup']

merged_df['Counter Ion Sites']
# Out:
# 43    17.0
# 44    44.0
# 45    22.0
# 46    26.0
# 47     4.0
# 48     8.0
# 49     1.0
# Name: Counter Ion Sites, dtype: float64

# %%
merged_df.rename(columns={"results_per_total": "Result_1"}, inplace=True)
# merged_df['Total Sites_x']

# %%
merged_df.sort_values(by='Result_1',inplace=True, ascending=False)

# %%
symbol = merged_df['Symbol_x'].values[0]
symbol
# Out:
# 'La'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create combined x-axis label

full_li = merged_df['Zn Sites']
merged_df['Anion Site'] = (merged_df['Counter Ion Sites'] / full_li).round(2)

merged_df.sort_values(by='Anion Site',inplace=True, ascending=False)
merged_df['Structure_SG'] = "Zn-" + symbol+(merged_df['Counter Ion Sites'] / full_li).round(2).astype(str) 
# Set data
x_labels = merged_df['Structure_SG']
values = merged_df['Result_1']

# Create figure
plt.figure(figsize=(10, 6))

# Create bar plot
x = np.arange(len(x_labels))  # numeric x-axis positions
plt.bar(x, values, width=0.6)

# X-axis setup
plt.xticks(x, x_labels, rotation=60, ha='right')
plt.xlabel('Structure')
plt.ylabel('Energy (mEh)')
# plt.title('Grouped Bar Plot of Result_1 by Structure and SpaceGroup')
# plt.legend(title='Metric')
plt.tight_layout()

# Save or show
plt.savefig(f'chemical_space/Zn_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()
