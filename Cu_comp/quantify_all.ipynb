# %%
import os
import numpy as np
import pandas as pd

import pymatgen as pg

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# %%
def local_min(df):

    df['dy'] = df['Edis'].diff()

    df['sign_dy'] = np.sign(df['dy'])
    df['sign_change'] = df['sign_dy'].diff()

    # Indices of local maxima: derivative goes from negative (-1) to positive (+1)
    local_min_indices = df.index[(df['sign_change'] > 0)]

    if len(local_min_indices) == 0:
        print('No local min found')
        return None
    local_mins = df.loc[local_min_indices, ['cell_length', 'Edis']].reset_index(drop=True)

    return local_mins

def local_max(df):
    df['dy'] = df['Edis'].diff()

    df['sign_dy'] = np.sign(df['dy'])
    df['sign_change'] = df['sign_dy'].diff()
    
    # Indices of local maxima: derivative goes from negative (-1) to positive (+1)
    local_min_indices = df.index[(df['sign_change'] < 0)]

    if len(local_min_indices) == 0:
        print('No local max found')
        return None
    local_max = df.loc[local_min_indices, ['cell_length', 'Edis']].reset_index(drop=True)
    return local_max

# %%
def finding_diff(df):
    abs_max = df['Edis'].iloc[-1]
    max_val = local_max(df)
    min_val = local_min(df)

    if max_val is None or min_val is None:
        return 0
    
    diff = (abs_max + max_val['Edis'][0])/2 - min_val['Edis'][0]

    return diff

# %%
from pymatgen.core import Structure

# %%
#list all folders inside li_d3s
li_d3s = os.listdir("d3_calcs")

results = []

df = pd.DataFrame()
cnt=0
for items in li_d3s:
    cnt+=1
    #get the path of each folder
    path = os.path.join("d3_calcs", items)
    # print(items)
    
    #ignore .DS_Store
    if items == ".DS_Store":
        continue
    file = os.path.join(path, f'{items}.csv')
    struct_file = os.path.join(path, 'POSCAR')
    df = pd.read_csv(file)
    print(f"Reading {file}")

    struct = Structure.from_file(struct_file)
    sites = struct.num_sites

    # print(struct.composition['Li'])
    li_sites = struct.composition['Cu']

    
    counter_ion_sites = struct.composition[struct.composition.elements[1]] if struct.composition.elements[0].symbol == 'Cu' else struct.composition[struct.composition.elements[0]]
    # print(f'Composition {struct.composition}')
    diff_energy = finding_diff(df)
    print(f'Composition {struct.composition}')
    print(f'diff per toal sites {diff_energy/sites}')
    print(f'diff per cation sites {diff_energy/li_sites}')
    print('-----------------------------------')

    result = {
        "Symbol": struct.composition.elements[0] if struct.composition.elements[0].symbol != 'Cu' else struct.composition.elements[1],
        "Structure": struct.composition,
        "Total Sites": sites,
        "Cation Sites": li_sites,
        "Counter Ion Sites": counter_ion_sites,
        "Diff Energy": diff_energy,
        "Diff per Total Sites": diff_energy/sites,
        "Diff per Cation Sites": diff_energy/li_sites,
        "Diff per Counter Ion Sites": diff_energy/counter_ion_sites,
        "Composition": str(struct.composition)
    }

    results.append(result)
print(f'total structure analysed = {cnt}')
# Out:
# Reading d3_calcs/Cu3Sb_20900/Cu3Sb_20900.csv
# Composition Cu6 Sb2
# diff per toal sites 0.008427942822591232
# diff per cation sites 0.011237257096788309
# -----------------------------------
# Reading d3_calcs/CuBr_23227/CuBr_23227.csv
# No local max found
# No local min found
# Composition Cu2 Br2
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/Ti2Cu_1192264/Ti2Cu_1192264.csv
# Composition Ti16 Cu8
# diff per toal sites 0.017254981737131064
# diff per cation sites 0.051764945211393194
# -----------------------------------
# Reading d3_calcs/LiCu3_1185338/LiCu3_1185338.csv
# Composition Li2 Cu6
# diff per toal sites 0.014243750556491061
# diff per cation sites 0.01899166740865475
# -----------------------------------
# Reading d3_calcs/CuPt3_1213433/CuPt3_1213433.csv
# Composition Cu1 Pt3
# diff per toal sites 0.003333707262442
# diff per cation sites 0.013334829049768
# -----------------------------------
# Reading d3_calcs/Cu4O3_1478/Cu4O3_1478.csv
# Composition Cu8 O6
# diff per toal sites 0.0027497828363273608
# diff per cation sites 0.004812119963572881
# -----------------------------------
# Reading d3_calcs/CuTe_1978391/CuTe_1978391.csv
# Composition Cu1 Te1
# diff per toal sites 0.00395916512039615
# diff per cation sites 0.0079183302407923
# -----------------------------------
# Reading d3_calcs/InCu_1018053/InCu_1018053.csv
# Composition In2 Cu2
# diff per toal sites 0.008793399559021
# diff per cation sites 0.017586799118042
# -----------------------------------
# Reading d3_calcs/Cu2O3_771359/Cu2O3_771359.csv
# Composition Cu16 O24
# diff per toal sites 0.0018321384637168497
# diff per cation sites 0.0045803461592921245
# -----------------------------------
# Reading d3_calcs/Cu3As4_633403/Cu3As4_633403.csv
# Composition Cu6 As8
# diff per toal sites 0.0031900549401621963
# diff per cation sites 0.007443461527045125
# -----------------------------------
# Reading d3_calcs/Mg3Cu_2479851/Mg3Cu_2479851.csv
# Composition Mg3 Cu1
# diff per toal sites 0.009732856056302464
# diff per cation sites 0.03893142422520986
# -----------------------------------
# Reading d3_calcs/CuI_22863/CuI_22863.csv
# Composition Cu2 I2
# diff per toal sites 0.00215555926215995
# diff per cation sites 0.0043111185243199
# -----------------------------------
# Reading d3_calcs/CuS2_684604/CuS2_684604.csv
# Composition Cu1 S2
# diff per toal sites 0.0014524823924206502
# diff per cation sites 0.00435744717726195
# -----------------------------------
# Reading d3_calcs/LaCu4_30589/LaCu4_30589.csv
# Composition La9 Cu36
# diff per toal sites 0.012426418744209869
# diff per cation sites 0.015533023430262336
# -----------------------------------
# Reading d3_calcs/CuO_510751/CuO_510751.csv
# Composition Cu16 O16
# diff per toal sites 0.0024162813584517498
# diff per cation sites 0.0048325627169034996
# -----------------------------------
# Reading d3_calcs/Cu17Se10_684605/Cu17Se10_684605.csv
# Composition Cu17 Se10
# diff per toal sites 0.004396161677745944
# diff per cation sites 0.006982139135243559
# -----------------------------------
# Reading d3_calcs/Cu3Te2_1225676/Cu3Te2_1225676.csv
# Composition Cu3 Te2
# diff per toal sites 0.004488607124156869
# diff per cation sites 0.0074810118735947825
# -----------------------------------
# Reading d3_calcs/GdCu6_1194708/GdCu6_1194708.csv
# Composition Gd4 Cu24
# diff per toal sites 0.0108447612883785
# diff per cation sites 0.01265222150310825
# -----------------------------------
# Reading d3_calcs/Zr2Cu_1077372/Zr2Cu_1077372.csv
# Composition Zr4 Cu2
# diff per toal sites 0.017275527856322418
# diff per cation sites 0.05182658356896726
# -----------------------------------
# Reading d3_calcs/Tb6Cu23_1192934/Tb6Cu23_1192934.csv
# Composition Tb6 Cu23
# diff per toal sites 0.015203131751877604
# diff per cation sites 0.019169166121932632
# -----------------------------------
# Reading d3_calcs/CuF2_1147672/CuF2_1147672.csv
# Composition Cu1 F2
# diff per toal sites 0.0005458209721155349
# diff per cation sites 0.0016374629163466046
# -----------------------------------
# Reading d3_calcs/Cu16I19_685158/Cu16I19_685158.csv
# Composition Cu16 I19
# diff per toal sites 0.0014363193735590282
# diff per cation sites 0.0031419486296603745
# -----------------------------------
# Reading d3_calcs/Cu2S_618991/Cu2S_618991.csv
# Composition Cu8 S4
# diff per toal sites 0.004626804759011887
# diff per cation sites 0.006940207138517831
# -----------------------------------
# Reading d3_calcs/Cu3F_1183996/Cu3F_1183996.csv
# Composition Cu6 F2
# diff per toal sites 0.005672063180987588
# diff per cation sites 0.0075627509079834515
# -----------------------------------
# Reading d3_calcs/HfCu3_865176/HfCu3_865176.csv
# Composition Hf1 Cu3
# diff per toal sites 0.009457180161339715
# diff per cation sites 0.012609573548452954
# -----------------------------------
# Reading d3_calcs/CuAu3_1184018/CuAu3_1184018.csv
# Composition Cu1 Au3
# diff per toal sites 0.010351695945431899
# diff per cation sites 0.041406783781727595
# -----------------------------------
# Reading d3_calcs/Cu3Pd_680639/Cu3Pd_680639.csv
# Composition Cu21 Pd7
# diff per toal sites 0.015395550406187628
# diff per cation sites 0.0205274005415835
# -----------------------------------
# Reading d3_calcs/CuTe_1238498/CuTe_1238498.csv
# Composition Cu2 Te2
# diff per toal sites 0.003956011851175513
# diff per cation sites 0.007912023702351025
# -----------------------------------
# Reading d3_calcs/Mg15Cu_1023610/Mg15Cu_1023610.csv
# Composition Mg15 Cu1
# diff per toal sites 0.011283827372114032
# diff per cation sites 0.1805412379538245
# -----------------------------------
# Reading d3_calcs/Cu3As_1184017/Cu3As_1184017.csv
# Composition Cu6 As2
# diff per toal sites 0.007558969109664975
# diff per cation sites 0.010078625479553299
# -----------------------------------
# Reading d3_calcs/CuS_504/CuS_504.csv
# Composition Cu6 S6
# diff per toal sites 0.0023980950633430836
# diff per cation sites 0.004796190126686167
# -----------------------------------
# Reading d3_calcs/MgCu3_1185856/MgCu3_1185856.csv
# Composition Mg1 Cu3
# diff per toal sites 0.010020574851413864
# diff per cation sites 0.013360766468551818
# -----------------------------------
# Reading d3_calcs/Cu14I19_685100/Cu14I19_685100.csv
# No local max found
# No local min found
# Composition Cu14 I19
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/CuN_1080203/CuN_1080203.csv
# Composition Cu2 N2
# diff per toal sites 0.003079576219264163
# diff per cation sites 0.006159152438528326
# -----------------------------------
# Reading d3_calcs/Cu2Se_16366/Cu2Se_16366.csv
# Composition Cu2 Se1
# diff per toal sites 0.005474682094551884
# diff per cation sites 0.008212023141827826
# -----------------------------------
# Reading d3_calcs/Cu3Ni_1225698/Cu3Ni_1225698.csv
# Composition Cu3 Ni1
# diff per toal sites 0.009347993131001212
# diff per cation sites 0.012463990841334949
# -----------------------------------
# Reading d3_calcs/CuTe2_1103235/CuTe2_1103235.csv
# Composition Cu4 Te8
# diff per toal sites 0.0033619009420647297
# diff per cation sites 0.01008570282619419
# -----------------------------------
# Reading d3_calcs/Cu9Se5_1173070/Cu9Se5_1173070.csv
# Composition Cu9 Se5
# diff per toal sites 0.003977914226662165
# diff per cation sites 0.006187866574807812
# -----------------------------------
# Reading d3_calcs/ScCu3_973092/ScCu3_973092.csv
# Composition Sc1 Cu3
# diff per toal sites 0.0117788811317384
# diff per cation sites 0.015705174842317867
# -----------------------------------
# Reading d3_calcs/Cu2Te_1861/Cu2Te_1861.csv
# Composition Cu4 Te2
# diff per toal sites 0.004335508787494909
# diff per cation sites 0.006503263181242363
# -----------------------------------
# Reading d3_calcs/ZrCu_2210/ZrCu_2210.csv
# Composition Zr1 Cu1
# diff per toal sites 0.0041910157695975
# diff per cation sites 0.008382031539195
# -----------------------------------
# Reading d3_calcs/In3Cu_974023/In3Cu_974023.csv
# Composition In6 Cu2
# diff per toal sites 0.006937334542059768
# diff per cation sites 0.02774933816823907
# -----------------------------------
# Reading d3_calcs/GaCu2_2281971/GaCu2_2281971.csv
# Composition Ga1 Cu2
# diff per toal sites 0.010310813708927984
# diff per cation sites 0.015466220563391976
# -----------------------------------
# Reading d3_calcs/Cu25Se26_684923/Cu25Se26_684923.csv
# Composition Cu75 Se78
# diff per toal sites 0.002391362172540127
# diff per cation sites 0.004878378831981859
# -----------------------------------
# Reading d3_calcs/CuS2_1068/CuS2_1068.csv
# Composition Cu4 S8
# diff per toal sites 0.002510692685141171
# diff per cation sites 0.007532078055423512
# -----------------------------------
# Reading d3_calcs/Cu3N_1933/Cu3N_1933.csv
# Composition Cu3 N1
# diff per toal sites 0.00453048499706995
# diff per cation sites 0.006040646662759933
# -----------------------------------
# Reading d3_calcs/Cu4Pd_30594/Cu4Pd_30594.csv
# Composition Cu16 Pd4
# diff per toal sites 0.012143530166611075
# diff per cation sites 0.015179412708263845
# -----------------------------------
# Reading d3_calcs/CeCu6_21708/CeCu6_21708.csv
# Composition Ce4 Cu24
# diff per toal sites 0.006907382271369964
# diff per cation sites 0.008058612649931624
# -----------------------------------
# Reading d3_calcs/CuI_1096937/CuI_1096937.csv
# Composition Cu1 I1
# diff per toal sites 0.002875250627962323
# diff per cation sites 0.005750501255924646
# -----------------------------------
# Reading d3_calcs/CuPd_1225701/CuPd_1225701.csv
# Composition Cu1 Pd1
# diff per toal sites 0.01722368327102685
# diff per cation sites 0.0344473665420537
# -----------------------------------
# Reading d3_calcs/CuO2_614565/CuO2_614565.csv
# Composition Cu1 O2
# diff per toal sites 0.0004912793186219166
# diff per cation sites 0.0014738379558657498
# -----------------------------------
# Reading d3_calcs/Cu10N3_1225831/Cu10N3_1225831.csv
# Composition Cu10 N3
# diff per toal sites 0.005567250471947347
# diff per cation sites 0.007237425613531551
# -----------------------------------
# Reading d3_calcs/Cu11S20_684964/Cu11S20_684964.csv
# Composition Cu11 S20
# diff per toal sites 0.0016554213028440966
# diff per cation sites 0.004665278217106091
# -----------------------------------
# Reading d3_calcs/Cu3Sb_1225736/Cu3Sb_1225736.csv
# Composition Cu3 Sb1
# diff per toal sites 0.005670334087610038
# diff per cation sites 0.0075604454501467175
# -----------------------------------
# Reading d3_calcs/CuTe_623012/CuTe_623012.csv
# Composition Cu2 Te2
# diff per toal sites 0.004056620236491463
# diff per cation sites 0.008113240472982926
# -----------------------------------
# Reading d3_calcs/Cu13Se8_32857/Cu13Se8_32857.csv
# Composition Cu13 Se8
# diff per toal sites 0.0042652405544660954
# diff per cation sites 0.006890003972599077
# -----------------------------------
# Reading d3_calcs/ZnCu3_1215529/ZnCu3_1215529.csv
# Composition Zn1 Cu3
# diff per toal sites 0.009949167533604074
# diff per cation sites 0.0132655567114721
# -----------------------------------
# Reading d3_calcs/ZnCu2_1215401/ZnCu2_1215401.csv
# Composition Zn1 Cu2
# diff per toal sites 0.009736080392823717
# diff per cation sites 0.014604120589235575
# -----------------------------------
# Reading d3_calcs/Fe3Cu_1184260/Fe3Cu_1184260.csv
# Composition Fe3 Cu1
# diff per toal sites 0.0037939787829824496
# diff per cation sites 0.015175915131929799
# -----------------------------------
# Reading d3_calcs/Cu3Ge_1184021/Cu3Ge_1184021.csv
# Composition Cu6 Ge2
# diff per toal sites 0.00991736396505907
# diff per cation sites 0.013223151953412093
# -----------------------------------
# Reading d3_calcs/LiCu3_974058/LiCu3_974058.csv
# Composition Li1 Cu3
# diff per toal sites 0.013982063827059013
# diff per cation sites 0.018642751769412016
# -----------------------------------
# Reading d3_calcs/ErCu5_30579/ErCu5_30579.csv
# Composition Er1 Cu5
# diff per toal sites 0.012147655228386468
# diff per cation sites 0.01457718627406376
# -----------------------------------
# Reading d3_calcs/Cu3O4_1147673/Cu3O4_1147673.csv
# Composition Cu6 O8
# diff per toal sites 0.001354376488035932
# diff per cation sites 0.003160211805417175
# -----------------------------------
# Reading d3_calcs/Cu3N_1203286/Cu3N_1203286.csv
# Composition Cu24 N8
# diff per toal sites 0.004831668291985344
# diff per cation sites 0.006442224389313792
# -----------------------------------
# Reading d3_calcs/ZnCu3_1215518/ZnCu3_1215518.csv
# Composition Zn1 Cu3
# diff per toal sites 0.010027324071737849
# diff per cation sites 0.013369765428983799
# -----------------------------------
# Reading d3_calcs/CdCu2_16775/CdCu2_16775.csv
# Composition Cd4 Cu8
# diff per toal sites 0.009104608294011333
# diff per cation sites 0.013656912441017
# -----------------------------------
# Reading d3_calcs/CuN8_1198545/CuN8_1198545.csv
# No local max found
# No local min found
# Composition Cu4 N32
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/PuCu2_1025032/PuCu2_1025032.csv
# Composition Pu2 Cu4
# diff per toal sites 0.01353465414250715
# diff per cation sites 0.020301981213760725
# -----------------------------------
# Reading d3_calcs/CuSe_568998/CuSe_568998.csv
# Composition Cu6 Se6
# diff per toal sites 0.0029602186786254372
# diff per cation sites 0.0059204373572508745
# -----------------------------------
# Reading d3_calcs/CuSn3_1184132/CuSn3_1184132.csv
# Composition Cu1 Sn3
# diff per toal sites 0.006009546131668601
# diff per cation sites 0.024038184526674403
# -----------------------------------
# Reading d3_calcs/Cu3N_1225717/Cu3N_1225717.csv
# Composition Cu3 N1
# diff per toal sites 0.0061176028447887994
# diff per cation sites 0.008156803793051733
# -----------------------------------
# Reading d3_calcs/Mg2Cu_865014/Mg2Cu_865014.csv
# Composition Mg4 Cu2
# diff per toal sites 0.0075950039345228405
# diff per cation sites 0.02278501180356852
# -----------------------------------
# Reading d3_calcs/Cu3Cl_1183968/Cu3Cl_1183968.csv
# Composition Cu3 Cl1
# diff per toal sites 0.006877324516372537
# diff per cation sites 0.00916976602183005
# -----------------------------------
# Reading d3_calcs/Cu3S2_1225731/Cu3S2_1225731.csv
# Composition Cu3 S2
# diff per toal sites 0.00424524937906768
# diff per cation sites 0.007075415631779466
# -----------------------------------
# Reading d3_calcs/CuO_25229/CuO_25229.csv
# Composition Cu4 O4
# diff per toal sites 0.0011067203343834249
# diff per cation sites 0.0022134406687668497
# -----------------------------------
# Reading d3_calcs/V3Cu_1187753/V3Cu_1187753.csv
# Composition V3 Cu1
# diff per toal sites 0.01817981882969125
# diff per cation sites 0.072719275318765
# -----------------------------------
# Reading d3_calcs/InCu3_1184858/InCu3_1184858.csv
# Composition In2 Cu6
# diff per toal sites 0.011239010740164706
# diff per cation sites 0.014985347653552942
# -----------------------------------
# Reading d3_calcs/CuS_1023128/CuS_1023128.csv
# Composition Cu1 S1
# diff per toal sites 0.004031409430845726
# diff per cation sites 0.008062818861691452
# -----------------------------------
# Reading d3_calcs/FeCu4_1224977/FeCu4_1224977.csv
# Composition Fe1 Cu4
# diff per toal sites 0.009612976313205509
# diff per cation sites 0.012016220391506887
# -----------------------------------
# Reading d3_calcs/Cu3Ag_1184011/Cu3Ag_1184011.csv
# Composition Cu3 Ag1
# diff per toal sites 0.011811943141660062
# diff per cation sites 0.015749257522213417
# -----------------------------------
# Reading d3_calcs/CaCu_30471/CaCu_30471.csv
# Composition Ca10 Cu10
# diff per toal sites 0.012797032690465776
# diff per cation sites 0.025594065380931553
# -----------------------------------
# Reading d3_calcs/Cu2As_7474/Cu2As_7474.csv
# Composition Cu4 As2
# diff per toal sites 0.006631697179580967
# diff per cation sites 0.00994754576937145
# -----------------------------------
# Reading d3_calcs/Cu3Sn_1195862/Cu3Sn_1195862.csv
# Composition Cu30 Sn10
# diff per toal sites 0.009180254226411938
# diff per cation sites 0.012240338968549251
# -----------------------------------
# Reading d3_calcs/CuO2_25378/CuO2_25378.csv
# Composition Cu1 O2
# diff per toal sites 0.0012228220173017
# diff per cation sites 0.0036684660519050996
# -----------------------------------
# Reading d3_calcs/CuC6_1213653/CuC6_1213653.csv
# Composition Cu1 C6
# diff per toal sites 0.0004053726555129142
# diff per cation sites 0.0028376085885903997
# -----------------------------------
# Reading d3_calcs/CuS2_850099/CuS2_850099.csv
# No local max found
# No local min found
# Composition Cu1 S2
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/GaCu4_1224832/GaCu4_1224832.csv
# Composition Ga1 Cu4
# diff per toal sites 0.00972993610596344
# diff per cation sites 0.0121624201324543
# -----------------------------------
# Reading d3_calcs/Al2Cu_12794/Al2Cu_12794.csv
# Composition Al2 Cu1
# diff per toal sites 0.007191035754347483
# diff per cation sites 0.02157310726304245
# -----------------------------------
# Reading d3_calcs/CuBr2_1147532/CuBr2_1147532.csv
# Composition Cu1 Br2
# diff per toal sites 0.0008076327396514851
# diff per cation sites 0.0024228982189544554
# -----------------------------------
# Reading d3_calcs/CuI_569346/CuI_569346.csv
# Composition Cu2 I2
# diff per toal sites 0.001564398359777475
# diff per cation sites 0.00312879671955495
# -----------------------------------
# Reading d3_calcs/YbCu2_1103426/YbCu2_1103426.csv
# Composition Yb4 Cu8
# diff per toal sites 0.016233243554742288
# diff per cation sites 0.024349865332113432
# -----------------------------------
# Reading d3_calcs/CuBr_32880/CuBr_32880.csv
# Composition Cu1 Br1
# diff per toal sites 0.00158146486510623
# diff per cation sites 0.00316292973021246
# -----------------------------------
# Reading d3_calcs/Cu5Sn4_845/Cu5Sn4_845.csv
# Composition Cu20 Sn16
# diff per toal sites 0.007448861590445043
# diff per cation sites 0.013407950862801077
# -----------------------------------
# Reading d3_calcs/Mg3Cu_978279/Mg3Cu_978279.csv
# Composition Mg3 Cu1
# diff per toal sites 0.008967906545121238
# diff per cation sites 0.03587162618048495
# -----------------------------------
# Reading d3_calcs/Cu5Ge2_1225722/Cu5Ge2_1225722.csv
# Composition Cu5 Ge2
# diff per toal sites 0.008047211270029242
# diff per cation sites 0.01126609577804094
# -----------------------------------
# Reading d3_calcs/Cu3Si_867317/Cu3Si_867317.csv
# Composition Cu6 Si2
# diff per toal sites 0.008290509170713882
# diff per cation sites 0.01105401222761851
# -----------------------------------
# Reading d3_calcs/BeCu_2323/BeCu_2323.csv
# Composition Be1 Cu1
# diff per toal sites 0.008830586498712174
# diff per cation sites 0.017661172997424347
# -----------------------------------
# Reading d3_calcs/Cu2Se_1097707/Cu2Se_1097707.csv
# Composition Cu96 Se48
# diff per toal sites 0.004023610063116789
# diff per cation sites 0.006035415094675183
# -----------------------------------
# Reading d3_calcs/Cu2S_581212/Cu2S_581212.csv
# Composition Cu96 S48
# diff per toal sites 0.004244934330687205
# diff per cation sites 0.0063674014960308075
# -----------------------------------
# Reading d3_calcs/CdCu3_1183623/CdCu3_1183623.csv
# Composition Cd1 Cu3
# diff per toal sites 0.008015628678509086
# diff per cation sites 0.010687504904678782
# -----------------------------------
# Reading d3_calcs/CuNi_1184069/CuNi_1184069.csv
# Composition Cu1 Ni1
# diff per toal sites 0.0107709938060156
# diff per cation sites 0.0215419876120312
# -----------------------------------
# Reading d3_calcs/CuI4_2766484/CuI4_2766484.csv
# No local max found
# No local min found
# Composition Cu1 I4
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/Cu3O4_1178476/Cu3O4_1178476.csv
# Composition Cu6 O8
# diff per toal sites 0.0021643728023830644
# diff per cation sites 0.005050203205560484
# -----------------------------------
# Reading d3_calcs/Lu6Cu23_1193217/Lu6Cu23_1193217.csv
# Composition Lu6 Cu23
# diff per toal sites 0.01263748338029155
# diff per cation sites 0.015934218175150217
# -----------------------------------
# Reading d3_calcs/EuCu_639675/EuCu_639675.csv
# Composition Eu1 Cu1
# diff per toal sites 0.021190544947009247
# diff per cation sites 0.042381089894018495
# -----------------------------------
# Reading d3_calcs/CuCl_1184046/CuCl_1184046.csv
# Composition Cu2 Cl2
# diff per toal sites 0.0015503569325635747
# diff per cation sites 0.0031007138651271493
# -----------------------------------
# Reading d3_calcs/PrCu6_30698/PrCu6_30698.csv
# Composition Pr4 Cu24
# diff per toal sites 0.012827910624164714
# diff per cation sites 0.014965895728192166
# -----------------------------------
# Reading d3_calcs/Cu9As4_1246371/Cu9As4_1246371.csv
# Composition Cu36 As16
# diff per toal sites 0.007669132726864722
# diff per cation sites 0.01107763616102682
# -----------------------------------
# Reading d3_calcs/Cu10Sn3_568495/Cu10Sn3_568495.csv
# Composition Cu20 Sn6
# diff per toal sites 0.009232586681603096
# diff per cation sites 0.012002362686084024
# -----------------------------------
# Reading d3_calcs/CuBi_569792/CuBi_569792.csv
# Composition Cu2 Bi2
# diff per toal sites 0.005151416243497574
# diff per cation sites 0.010302832486995149
# -----------------------------------
# Reading d3_calcs/CuB5_1181765/CuB5_1181765.csv
# Composition Cu16 B80
# diff per toal sites 0.0026887182352720827
# diff per cation sites 0.016132309411632496
# -----------------------------------
# Reading d3_calcs/CuB5_1201287/CuB5_1201287.csv
# Composition Cu16 B80
# diff per toal sites 0.002571083049252448
# diff per cation sites 0.01542649829551469
# -----------------------------------
# Reading d3_calcs/FeCu3_1184444/FeCu3_1184444.csv
# Composition Fe2 Cu6
# diff per toal sites 0.009276670224345748
# diff per cation sites 0.012368893632460997
# -----------------------------------
# Reading d3_calcs/CuAg3_984351/CuAg3_984351.csv
# Composition Cu2 Ag6
# diff per toal sites 0.00847270956425267
# diff per cation sites 0.03389083825701068
# -----------------------------------
# Reading d3_calcs/Cu3Te_1183984/Cu3Te_1183984.csv
# Composition Cu3 Te1
# diff per toal sites 0.007405068134955274
# diff per cation sites 0.009873424179940365
# -----------------------------------
# Reading d3_calcs/AlCu3_1183216/AlCu3_1183216.csv
# Composition Al2 Cu6
# diff per toal sites 0.010689700377319438
# diff per cation sites 0.014252933836425917
# -----------------------------------
# Reading d3_calcs/In4Cu9_683917/In4Cu9_683917.csv
# Composition In16 Cu36
# diff per toal sites 0.010413938168107355
# diff per cation sites 0.015042355131710625
# -----------------------------------
# Reading d3_calcs/In9Cu11_1188928/In9Cu11_1188928.csv
# Composition In9 Cu11
# diff per toal sites 0.01018268964868585
# diff per cation sites 0.018513981179428818
# -----------------------------------
# Reading d3_calcs/CuSn3_1184173/CuSn3_1184173.csv
# Composition Cu2 Sn6
# diff per toal sites 0.006329798981807313
# diff per cation sites 0.02531919592722925
# -----------------------------------
# Reading d3_calcs/Cu3P_14012/Cu3P_14012.csv
# Composition Cu18 P6
# diff per toal sites 0.006492186667561896
# diff per cation sites 0.008656248890082529
# -----------------------------------
# Reading d3_calcs/CuN3_504768/CuN3_504768.csv
# No local max found
# No local min found
# Composition Cu4 N12
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/CuAu3_2103/CuAu3_2103.csv
# Composition Cu1 Au3
# diff per toal sites 0.010371265430334037
# diff per cation sites 0.04148506172133615
# -----------------------------------
# Reading d3_calcs/Cu3N_13480/Cu3N_13480.csv
# Composition Cu3 N1
# diff per toal sites 0.0061196756390196755
# diff per cation sites 0.0081595675186929
# -----------------------------------
# Reading d3_calcs/Cu3P_359/Cu3P_359.csv
# Composition Cu18 P6
# diff per toal sites 0.006977362180819416
# diff per cation sites 0.009303149574425887
# -----------------------------------
# Reading d3_calcs/Cu19Se11_684970/Cu19Se11_684970.csv
# Composition Cu19 Se11
# diff per toal sites 0.004508374693951451
# diff per cation sites 0.007118486358870712
# -----------------------------------
# Reading d3_calcs/Cu2Se_22297/Cu2Se_22297.csv
# Composition Cu2 Se1
# diff per toal sites 0.004891592148889034
# diff per cation sites 0.007337388223333551
# -----------------------------------
# Reading d3_calcs/CuI_32750/CuI_32750.csv
# Composition Cu4 I4
# diff per toal sites 0.001562642372178975
# diff per cation sites 0.00312528474435795
# -----------------------------------
# Reading d3_calcs/Cu3Sb_1183969/Cu3Sb_1183969.csv
# Composition Cu3 Sb1
# diff per toal sites 0.008616512955415512
# diff per cation sites 0.011488683940554016
# -----------------------------------
# Reading d3_calcs/CuH_1225705/CuH_1225705.csv
# Composition Cu2 H2
# diff per toal sites 0.005621259953011225
# diff per cation sites 0.01124251990602245
# -----------------------------------
# Reading d3_calcs/DyCu7_1225716/DyCu7_1225716.csv
# Composition Dy3 Cu21
# diff per toal sites 0.010015876587929481
# diff per cation sites 0.011446716100490835
# -----------------------------------
# Reading d3_calcs/Cu3N_1225758/Cu3N_1225758.csv
# Composition Cu3 N1
# diff per toal sites 0.006272761281141726
# diff per cation sites 0.008363681708188969
# -----------------------------------
# Reading d3_calcs/Zr3Cu_580287/Zr3Cu_580287.csv
# Composition Zr3 Cu1
# diff per toal sites 0.017897726013883012
# diff per cation sites 0.07159090405553205
# -----------------------------------
# Reading d3_calcs/ScCu3_973100/ScCu3_973100.csv
# Composition Sc1 Cu3
# diff per toal sites 0.011055216114237576
# diff per cation sites 0.014740288152316768
# -----------------------------------
# Reading d3_calcs/CuN3_27954/CuN3_27954.csv
# No local max found
# No local min found
# Composition Cu4 N12
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/Cu3As_7634/Cu3As_7634.csv
# Composition Cu18 As6
# diff per toal sites 0.007245709025733124
# diff per cation sites 0.009660945367644166
# -----------------------------------
# Reading d3_calcs/Cu4As_1246292/Cu4As_1246292.csv
# Composition Cu16 As4
# diff per toal sites 0.007850903184302602
# diff per cation sites 0.009813628980378252
# -----------------------------------
# Reading d3_calcs/Cd5Cu2_30696/Cd5Cu2_30696.csv
# Composition Cd20 Cu8
# diff per toal sites 0.008548487787473856
# diff per cation sites 0.029919707256158497
# -----------------------------------
# Reading d3_calcs/AlCu_1022721/AlCu_1022721.csv
# Composition Al1 Cu1
# diff per toal sites 0.010590314737807102
# diff per cation sites 0.021180629475614204
# -----------------------------------
# Reading d3_calcs/CeCu_636198/CeCu_636198.csv
# Composition Ce4 Cu4
# diff per toal sites 0.00403052088968198
# diff per cation sites 0.00806104177936396
# -----------------------------------
# Reading d3_calcs/CuAu_582681/CuAu_582681.csv
# Composition Cu10 Au10
# diff per toal sites 0.010757274000457126
# diff per cation sites 0.021514548000914253
# -----------------------------------
# Reading d3_calcs/CuO_1064456/CuO_1064456.csv
# Composition Cu2 O2
# diff per toal sites 0.002197341658761088
# diff per cation sites 0.004394683317522176
# -----------------------------------
# Reading d3_calcs/CuSe_582060/CuSe_582060.csv
# Composition Cu6 Se6
# diff per toal sites 0.0029388819125383044
# diff per cation sites 0.005877763825076609
# -----------------------------------
# Reading d3_calcs/Cu3As_1966/Cu3As_1966.csv
# Composition Cu24 As8
# diff per toal sites 0.006978216527480078
# diff per cation sites 0.00930428870330677
# -----------------------------------
# Reading d3_calcs/Cu2S_553942/Cu2S_553942.csv
# Composition Cu4 S2
# diff per toal sites 0.0045556605359681245
# diff per cation sites 0.006833490803952187
# -----------------------------------
# Reading d3_calcs/In3Cu_1184480/In3Cu_1184480.csv
# Composition In3 Cu1
# diff per toal sites 0.008290472834672123
# diff per cation sites 0.03316189133868849
# -----------------------------------
# Reading d3_calcs/CuCl3_1213141/CuCl3_1213141.csv
# No local max found
# No local min found
# Composition Cu4 Cl12
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/MnCu3_974747/MnCu3_974747.csv
# Composition Mn2 Cu6
# diff per toal sites 0.003898994263046687
# diff per cation sites 0.005198659017395583
# -----------------------------------
# Reading d3_calcs/CuPd_1225656/CuPd_1225656.csv
# Composition Cu1 Pd1
# diff per toal sites 0.016490407544692852
# diff per cation sites 0.032980815089385704
# -----------------------------------
# Reading d3_calcs/Zr2Cu_583800/Zr2Cu_583800.csv
# Composition Zr16 Cu8
# diff per toal sites 0.017477789214780087
# diff per cation sites 0.052433367644340256
# -----------------------------------
# Reading d3_calcs/Dy6Cu23_1194041/Dy6Cu23_1194041.csv
# Composition Dy6 Cu23
# diff per toal sites 0.014570974577001364
# diff per cation sites 0.01837209837969737
# -----------------------------------
# Reading d3_calcs/TbCu5_1077262/TbCu5_1077262.csv
# Composition Tb1 Cu5
# diff per toal sites 0.012777613864323608
# diff per cation sites 0.01533313663718833
# -----------------------------------
# Reading d3_calcs/Cu9Se8_673255/Cu9Se8_673255.csv
# Composition Cu9 Se8
# diff per toal sites 0.002834201769663977
# diff per cation sites 0.005353492231587512
# -----------------------------------
# Reading d3_calcs/Mn4Cu_1221725/Mn4Cu_1221725.csv
# Composition Mn4 Cu1
# diff per toal sites 0.003626113870417501
# diff per cation sites 0.018130569352087504
# -----------------------------------
# Reading d3_calcs/Cu8O_704745/Cu8O_704745.csv
# Composition Cu8 O1
# diff per toal sites 0.007321614181525234
# diff per cation sites 0.008236815954215888
# -----------------------------------
# Reading d3_calcs/Yb3Cu_1187968/Yb3Cu_1187968.csv
# Composition Yb3 Cu1
# diff per toal sites 0.021300048809073914
# diff per cation sites 0.08520019523629566
# -----------------------------------
# Reading d3_calcs/Cu2S_674831/Cu2S_674831.csv
# Composition Cu12 S6
# diff per toal sites 0.0039632615463479175
# diff per cation sites 0.005944892319521875
# -----------------------------------
# Reading d3_calcs/In9Cu11_1224313/In9Cu11_1224313.csv
# Composition In9 Cu11
# diff per toal sites 0.009573175700551525
# diff per cation sites 0.01740577400100277
# -----------------------------------
# Reading d3_calcs/Cu81Sn22_1227576/Cu81Sn22_1227576.csv
# Composition Cu81 Sn22
# diff per toal sites 0.009029207191055778
# diff per cation sites 0.011481584452824012
# -----------------------------------
# Reading d3_calcs/DyCu5_30578/DyCu5_30578.csv
# Composition Dy1 Cu5
# diff per toal sites 0.012263004506780958
# diff per cation sites 0.01471560540813715
# -----------------------------------
# Reading d3_calcs/CuO_704645/CuO_704645.csv
# Composition Cu2 O2
# diff per toal sites 0.00270610975823915
# diff per cation sites 0.0054122195164783
# -----------------------------------
# Reading d3_calcs/AlCu3_1008555/AlCu3_1008555.csv
# Composition Al1 Cu3
# diff per toal sites 0.010677127108681513
# diff per cation sites 0.014236169478242017
# -----------------------------------
# Reading d3_calcs/CuAu3_1184004/CuAu3_1184004.csv
# No local max found
# No local min found
# Composition Cu2 Au6
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/CuN_1008923/CuN_1008923.csv
# Composition Cu1 N1
# diff per toal sites 0.004959583285694125
# diff per cation sites 0.00991916657138825
# -----------------------------------
# Reading d3_calcs/Mg3Cu_1016224/Mg3Cu_1016224.csv
# Composition Mg3 Cu1
# diff per toal sites 0.008587603540484988
# diff per cation sites 0.03435041416193995
# -----------------------------------
# Reading d3_calcs/Cu11S16_675278/Cu11S16_675278.csv
# Composition Cu11 S16
# diff per toal sites 0.0019333698957361115
# diff per cation sites 0.004745544289534092
# -----------------------------------
# Reading d3_calcs/CuSe_580226/CuSe_580226.csv
# Composition Cu2 Se2
# diff per toal sites 0.0033574455789545494
# diff per cation sites 0.006714891157909099
# -----------------------------------
# Reading d3_calcs/Th2Cu_1034/Th2Cu_1034.csv
# Composition Th4 Cu2
# diff per toal sites 0.015000611408295833
# diff per cation sites 0.0450018342248875
# -----------------------------------
# Reading d3_calcs/CuI4_2745918/CuI4_2745918.csv
# No local max found
# No local min found
# Composition Cu1 I4
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/Ti2Cu3_622570/Ti2Cu3_622570.csv
# Composition Ti4 Cu6
# diff per toal sites 0.011385474965429349
# diff per cation sites 0.018975791609048914
# -----------------------------------
# Reading d3_calcs/CuPb3_1184185/CuPb3_1184185.csv
# Composition Cu1 Pb3
# diff per toal sites 0.006174823579619451
# diff per cation sites 0.024699294318477803
# -----------------------------------
# Reading d3_calcs/LiCu3_1185312/LiCu3_1185312.csv
# Composition Li1 Cu3
# diff per toal sites 0.014197536644771075
# diff per cation sites 0.018930048859694768
# -----------------------------------
# Reading d3_calcs/CuO2_654801/CuO2_654801.csv
# Composition Cu1 O2
# diff per toal sites 0.00034911763352286836
# diff per cation sites 0.001047352900568605
# -----------------------------------
# Reading d3_calcs/Cu3N_1078576/Cu3N_1078576.csv
# Composition Cu6 N2
# diff per toal sites 0.003511804322888337
# diff per cation sites 0.004682405763851116
# -----------------------------------
# Reading d3_calcs/Cu7Si6_1213668/Cu7Si6_1213668.csv
# Composition Cu7 Si6
# diff per toal sites 0.0006841638615262539
# diff per cation sites 0.0012705900285487572
# -----------------------------------
# Reading d3_calcs/Cu29Se19_685189/Cu29Se19_685189.csv
# Composition Cu29 Se19
# diff per toal sites 0.0041223010471197604
# diff per cation sites 0.006823118974543053
# -----------------------------------
# Reading d3_calcs/NdCu6_1945/NdCu6_1945.csv
# Composition Nd4 Cu24
# diff per toal sites 0.01267453730973893
# diff per cation sites 0.01478696019469542
# -----------------------------------
# Reading d3_calcs/Cu3O2_1022728/Cu3O2_1022728.csv
# Composition Cu3 O2
# diff per toal sites 0.0033676081460052598
# diff per cation sites 0.005612680243342099
# -----------------------------------
# Reading d3_calcs/Cu4O3_1023130/Cu4O3_1023130.csv
# Composition Cu8 O6
# diff per toal sites 0.004079081430068068
# diff per cation sites 0.0071383925026191185
# -----------------------------------
# Reading d3_calcs/CuS2_1147712/CuS2_1147712.csv
# No local max found
# No local min found
# Composition Cu4 S8
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/Cu2Se_1021499/Cu2Se_1021499.csv
# Composition Cu8 Se4
# diff per toal sites 0.004224073361468554
# diff per cation sites 0.006336110042202831
# -----------------------------------
# Reading d3_calcs/Ce3Cu_1006330/Ce3Cu_1006330.csv
# Composition Ce3 Cu1
# diff per toal sites 0.0034866216050217
# diff per cation sites 0.0139464864200868
# -----------------------------------
# Reading d3_calcs/HfCu3_1184704/HfCu3_1184704.csv
# Composition Hf1 Cu3
# diff per toal sites 0.010029997344153852
# diff per cation sites 0.013373329792205136
# -----------------------------------
# Reading d3_calcs/Cu2S_1225993/Cu2S_1225993.csv
# Composition Cu4 S2
# diff per toal sites 0.0019666431021221334
# diff per cation sites 0.0029499646531832
# -----------------------------------
# Reading d3_calcs/Cu7Hg6_628808/Cu7Hg6_628808.csv
# Composition Cu14 Hg12
# diff per toal sites 0.004343366675431153
# diff per cation sites 0.008066252397229285
# -----------------------------------
# Reading d3_calcs/AlCu4_1182885/AlCu4_1182885.csv
# Composition Al4 Cu16
# diff per toal sites 0.009902711380324527
# diff per cation sites 0.012378389225405658
# -----------------------------------
# Reading d3_calcs/Tl3Cu_1187546/Tl3Cu_1187546.csv
# Composition Tl3 Cu1
# diff per toal sites 0.008146563766143563
# diff per cation sites 0.03258625506457425
# -----------------------------------
# Reading d3_calcs/CuI_570136/CuI_570136.csv
# Composition Cu6 I6
# diff per toal sites 0.0022004079954633248
# diff per cation sites 0.0044008159909266495
# -----------------------------------
# Reading d3_calcs/YCu2_1102436/YCu2_1102436.csv
# Composition Y4 Cu8
# diff per toal sites 0.016499604176083666
# diff per cation sites 0.0247494062641255
# -----------------------------------
# Reading d3_calcs/ZnCu_1215462/ZnCu_1215462.csv
# Composition Zn1 Cu1
# diff per toal sites 0.008019292836278951
# diff per cation sites 0.016038585672557903
# -----------------------------------
# Reading d3_calcs/Al3Cu2_10886/Al3Cu2_10886.csv
# Composition Al3 Cu2
# diff per toal sites 0.008560621516622662
# diff per cation sites 0.021401553791556654
# -----------------------------------
# Reading d3_calcs/V3Cu_979283/V3Cu_979283.csv
# Composition V3 Cu1
# diff per toal sites 0.017431231273015
# diff per cation sites 0.06972492509206
# -----------------------------------
# Reading d3_calcs/Mg4Cu_1210855/Mg4Cu_1210855.csv
# Composition Mg8 Cu2
# diff per toal sites 0.0060548328618672195
# diff per cation sites 0.030274164309336098
# -----------------------------------
# Reading d3_calcs/Cu3As_1246900/Cu3As_1246900.csv
# Composition Cu3 As1
# diff per toal sites 0.0072511549439598
# diff per cation sites 0.0096682065919464
# -----------------------------------
# Reading d3_calcs/CuS2_849086/CuS2_849086.csv
# Composition Cu2 S4
# diff per toal sites 0.002429980749338192
# diff per cation sites 0.0072899422480145765
# -----------------------------------
# Reading d3_calcs/Cu3Ge_1225745/Cu3Ge_1225745.csv
# Composition Cu3 Ge1
# diff per toal sites 0.008701817781205198
# diff per cation sites 0.011602423708273598
# -----------------------------------
# Reading d3_calcs/Sr3Cu_1187104/Sr3Cu_1187104.csv
# Composition Sr3 Cu1
# diff per toal sites 0.0027202260177842
# diff per cation sites 0.0108809040711368
# -----------------------------------
# Reading d3_calcs/Cu2O3_755928/Cu2O3_755928.csv
# Composition Cu8 O12
# diff per toal sites 0.0016114829166467923
# diff per cation sites 0.004028707291616981
# -----------------------------------
# Reading d3_calcs/Cu3P_7463/Cu3P_7463.csv
# Composition Cu18 P6
# diff per toal sites 0.006440997658052667
# diff per cation sites 0.008587996877403557
# -----------------------------------
# Reading d3_calcs/CuCl_571386/CuCl_571386.csv
# Composition Cu1 Cl1
# diff per toal sites 0.0030193887602538074
# diff per cation sites 0.006038777520507615
# -----------------------------------
# Reading d3_calcs/Cu9S5_542333/Cu9S5_542333.csv
# Composition Cu9 S5
# diff per toal sites 0.004136250608238461
# diff per cation sites 0.006434167612815383
# -----------------------------------
# Reading d3_calcs/CuN_1008922/CuN_1008922.csv
# Composition Cu1 N1
# diff per toal sites 0.004297212615397901
# diff per cation sites 0.008594425230795802
# -----------------------------------
# Reading d3_calcs/CuO_510752/CuO_510752.csv
# Composition Cu8 O8
# diff per toal sites 0.0021617190376202245
# diff per cation sites 0.004323438075240449
# -----------------------------------
# Reading d3_calcs/CuSe2_2280/CuSe2_2280.csv
# Composition Cu4 Se8
# diff per toal sites 0.0030726047609347627
# diff per cation sites 0.009217814282804288
# -----------------------------------
# Reading d3_calcs/CuI_1007922/CuI_1007922.csv
# Composition Cu2 I2
# diff per toal sites 0.0017344516673498125
# diff per cation sites 0.003468903334699625
# -----------------------------------
# Reading d3_calcs/Cu9O13_1045694/Cu9O13_1045694.csv
# Composition Cu9 O13
# diff per toal sites 0.00201821929527393
# diff per cation sites 0.00493342494400294
# -----------------------------------
# Reading d3_calcs/Cu3Sn_13138/Cu3Sn_13138.csv
# Composition Cu6 Sn2
# diff per toal sites 0.00943693637628142
# diff per cation sites 0.012582581835041892
# -----------------------------------
# Reading d3_calcs/ZrCu_1080022/ZrCu_1080022.csv
# Composition Zr4 Cu4
# diff per toal sites 0.004046209628666687
# diff per cation sites 0.008092419257333373
# -----------------------------------
# Reading d3_calcs/Ce3Cu_1183872/Ce3Cu_1183872.csv
# No local max found
# No local min found
# Composition Ce3 Cu1
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/CuGe3_1184147/CuGe3_1184147.csv
# Composition Cu2 Ge6
# diff per toal sites 0.006272886263960169
# diff per cation sites 0.025091545055840676
# -----------------------------------
# Reading d3_calcs/NaCu_976292/NaCu_976292.csv
# Composition Na1 Cu1
# diff per toal sites 0.00461312293809215
# diff per cation sites 0.0092262458761843
# -----------------------------------
# Reading d3_calcs/K3Cu_1184878/K3Cu_1184878.csv
# Composition K3 Cu1
# diff per toal sites 0.009698499780178636
# diff per cation sites 0.038793999120714545
# -----------------------------------
# Reading d3_calcs/Cu9S5_685108/Cu9S5_685108.csv
# Composition Cu9 S5
# diff per toal sites 0.004459239506904093
# diff per cation sites 0.006936594788517477
# -----------------------------------
# Reading d3_calcs/CuPd3_1184119/CuPd3_1184119.csv
# Composition Cu1 Pd3
# diff per toal sites 0.008410043025579288
# diff per cation sites 0.03364017210231715
# -----------------------------------
# Reading d3_calcs/TiCu3_12546/TiCu3_12546.csv
# Composition Ti2 Cu6
# diff per toal sites 0.010839924525261002
# diff per cation sites 0.014453232700348003
# -----------------------------------
# Reading d3_calcs/Mg2Cu_1052023/Mg2Cu_1052023.csv
# Composition Mg4 Cu2
# diff per toal sites 0.008575307525878834
# diff per cation sites 0.025725922577636503
# -----------------------------------
# Reading d3_calcs/CuBr_23212/CuBr_23212.csv
# Composition Cu8 Br8
# diff per toal sites 0.0019755048915375277
# diff per cation sites 0.0039510097830750554
# -----------------------------------
# Reading d3_calcs/Al4Cu15_1228752/Al4Cu15_1228752.csv
# Composition Al4 Cu15
# diff per toal sites 0.01060759169995308
# diff per cation sites 0.013436282819940566
# -----------------------------------
# Reading d3_calcs/Al2Cu_998/Al2Cu_998.csv
# Composition Al4 Cu2
# diff per toal sites 0.007905601237807735
# diff per cation sites 0.023716803713423204
# -----------------------------------
# Reading d3_calcs/Cu3Pd2_1225751/Cu3Pd2_1225751.csv
# Composition Cu6 Pd4
# diff per toal sites 0.01820051689661295
# diff per cation sites 0.03033419482768825
# -----------------------------------
# Reading d3_calcs/Cu8O7_32905/Cu8O7_32905.csv
# Composition Cu8 O7
# diff per toal sites 0.002920833461697987
# diff per cation sites 0.005476562740683725
# -----------------------------------
# Reading d3_calcs/CuGe3_1025440/CuGe3_1025440.csv
# Composition Cu2 Ge6
# diff per toal sites 0.004320281880179058
# diff per cation sites 0.01728112752071623
# -----------------------------------
# Reading d3_calcs/Eu2Cu_1102243/Eu2Cu_1102243.csv
# Composition Eu8 Cu4
# diff per toal sites 0.02107861944279829
# diff per cation sites 0.06323585832839487
# -----------------------------------
# Reading d3_calcs/Cu9S16_685056/Cu9S16_685056.csv
# Composition Cu9 S16
# diff per toal sites 0.00157939479133272
# diff per cation sites 0.004387207753702
# -----------------------------------
# Reading d3_calcs/CuF2_1147670/CuF2_1147670.csv
# Composition Cu1 F2
# diff per toal sites 0.00033619070289428996
# diff per cation sites 0.00100857210868287
# -----------------------------------
# Reading d3_calcs/CuH_24093/CuH_24093.csv
# Composition Cu2 H2
# diff per toal sites 0.005407055029665275
# diff per cation sites 0.01081411005933055
# -----------------------------------
# Reading d3_calcs/MgCu_972916/MgCu_972916.csv
# Composition Mg2 Cu2
# diff per toal sites 0.009163066955686274
# diff per cation sites 0.01832613391137255
# -----------------------------------
# Reading d3_calcs/CuN_1425089/CuN_1425089.csv
# Composition Cu2 N2
# diff per toal sites 0.0011348060344781503
# diff per cation sites 0.0022696120689563006
# -----------------------------------
# Reading d3_calcs/Fe3Cu_1184311/Fe3Cu_1184311.csv
# Composition Fe3 Cu1
# diff per toal sites 0.004036900554954674
# diff per cation sites 0.016147602219818695
# -----------------------------------
# Reading d3_calcs/Cu6O_1207322/Cu6O_1207322.csv
# Composition Cu6 O1
# diff per toal sites 0.0015052505399276287
# diff per cation sites 0.0017561256299155668
# -----------------------------------
# Reading d3_calcs/Nd3Cu_1186272/Nd3Cu_1186272.csv
# Composition Nd3 Cu1
# diff per toal sites 0.024304313602600776
# diff per cation sites 0.0972172544104031
# -----------------------------------
# Reading d3_calcs/CuI2_1213016/CuI2_1213016.csv
# No local max found
# No local min found
# Composition Cu1 I2
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/ZnCu_2034504/ZnCu_2034504.csv
# Composition Zn1 Cu1
# diff per toal sites 0.008211094943012025
# diff per cation sites 0.01642218988602405
# -----------------------------------
# Reading d3_calcs/GaCu2_1077001/GaCu2_1077001.csv
# Composition Ga2 Cu4
# diff per toal sites 0.010297393842044849
# diff per cation sites 0.015446090763067273
# -----------------------------------
# Reading d3_calcs/FeCu_1224945/FeCu_1224945.csv
# Composition Fe1 Cu1
# diff per toal sites 0.004122406309261
# diff per cation sites 0.008244812618522
# -----------------------------------
# Reading d3_calcs/Cu4Se3_1225796/Cu4Se3_1225796.csv
# Composition Cu4 Se3
# diff per toal sites 0.0042456881582432285
# diff per cation sites 0.00742995427692565
# -----------------------------------
# Reading d3_calcs/CuGe3_1184183/CuGe3_1184183.csv
# Composition Cu1 Ge3
# diff per toal sites 0.006069962514572687
# diff per cation sites 0.02427985005829075
# -----------------------------------
# Reading d3_calcs/Cu8O_31217/Cu8O_31217.csv
# Composition Cu8 O1
# diff per toal sites 0.006620810091848683
# diff per cation sites 0.0074484113533297685
# -----------------------------------
# Reading d3_calcs/GaCu3_1184001/GaCu3_1184001.csv
# Composition Ga1 Cu3
# diff per toal sites 0.011927821209086188
# diff per cation sites 0.015903761612114917
# -----------------------------------
# Reading d3_calcs/CuI_22895/CuI_22895.csv
# Composition Cu4 I4
# diff per toal sites 0.0015599865354464061
# diff per cation sites 0.0031199730708928123
# -----------------------------------
# Reading d3_calcs/ZrCu_1067210/ZrCu_1067210.csv
# Composition Zr2 Cu2
# diff per toal sites 0.0040735051065252745
# diff per cation sites 0.008147010213050549
# -----------------------------------
# Reading d3_calcs/CeCu5_761/CeCu5_761.csv
# Composition Ce1 Cu5
# diff per toal sites 0.006322272343516233
# diff per cation sites 0.007586726812219479
# -----------------------------------
# Reading d3_calcs/NaCu3_982381/NaCu3_982381.csv
# Composition Na1 Cu3
# diff per toal sites 0.011280804004525462
# diff per cation sites 0.015041072006033948
# -----------------------------------
# Reading d3_calcs/TiCu_11364/TiCu_11364.csv
# Composition Ti1 Cu1
# diff per toal sites 0.0174353875792572
# diff per cation sites 0.0348707751585144
# -----------------------------------
# Reading d3_calcs/CuCl_22914/CuCl_22914.csv
# Composition Cu1 Cl1
# diff per toal sites 0.0015486123788596628
# diff per cation sites 0.0030972247577193256
# -----------------------------------
# Reading d3_calcs/CuAu_1225677/CuAu_1225677.csv
# Composition Cu1 Au1
# diff per toal sites 0.010326132900319748
# diff per cation sites 0.020652265800639495
# -----------------------------------
# Reading d3_calcs/LaCu6_636256/LaCu6_636256.csv
# Composition La4 Cu24
# diff per toal sites 0.01120679621130584
# diff per cation sites 0.013074595579856815
# -----------------------------------
# Reading d3_calcs/SmCu_12586/SmCu_12586.csv
# Composition Sm1 Cu1
# diff per toal sites 0.020957602375239852
# diff per cation sites 0.041915204750479704
# -----------------------------------
# Reading d3_calcs/SmCu6_30699/SmCu6_30699.csv
# Composition Sm4 Cu24
# diff per toal sites 0.011657279772246286
# diff per cation sites 0.013600159734287333
# -----------------------------------
# Reading d3_calcs/CuO2_601195/CuO2_601195.csv
# Composition Cu2 O4
# diff per toal sites 0.0003686455835556167
# diff per cation sites 0.0011059367506668501
# -----------------------------------
# Reading d3_calcs/CuTe2_1207193/CuTe2_1207193.csv
# Composition Cu1 Te2
# diff per toal sites 0.0032831814828008492
# diff per cation sites 0.009849544448402548
# -----------------------------------
# Reading d3_calcs/Ti2Cu3_30599/Ti2Cu3_30599.csv
# Composition Ti2 Cu3
# diff per toal sites 0.011200254923127432
# diff per cation sites 0.01866709153854572
# -----------------------------------
# Reading d3_calcs/CuI2_1147667/CuI2_1147667.csv
# Composition Cu1 I2
# diff per toal sites 0.0010331909518035269
# diff per cation sites 0.0030995728554105806
# -----------------------------------
# Reading d3_calcs/Cu27Se20_684606/Cu27Se20_684606.csv
# Composition Cu27 Se20
# diff per toal sites 0.003410174666844989
# diff per cation sites 0.0059362299756190555
# -----------------------------------
# Reading d3_calcs/Th2Cu_579718/Th2Cu_579718.csv
# Composition Th2 Cu1
# diff per toal sites 0.006803621657475202
# diff per cation sites 0.020410864972425606
# -----------------------------------
# Reading d3_calcs/UCu5_510148/UCu5_510148.csv
# Composition U1 Cu5
# diff per toal sites 0.013720062838606292
# diff per cation sites 0.01646407540632755
# -----------------------------------
# Reading d3_calcs/Cu2S_2831205/Cu2S_2831205.csv
# Composition Cu4 S2
# diff per toal sites 0.003763925699476541
# diff per cation sites 0.005645888549214812
# -----------------------------------
# Reading d3_calcs/Cu2S_1225835/Cu2S_1225835.csv
# Composition Cu4 S2
# diff per toal sites 0.003337523384633208
# diff per cation sites 0.005006285076949812
# ...
# diff per cation sites 0.07420444265761295
# -----------------------------------
# Reading d3_calcs/CuO_14549/CuO_14549.csv
# Composition Cu1 O1
# diff per toal sites 0.0036043997496331276
# diff per cation sites 0.007208799499266255
# -----------------------------------
# Reading d3_calcs/Cu3P_7540/Cu3P_7540.csv
# Composition Cu6 P2
# diff per toal sites 0.006288070477372249
# diff per cation sites 0.008384093969829665
# -----------------------------------
# Reading d3_calcs/CuAs_12070/CuAs_12070.csv
# Composition Cu2 As2
# diff per toal sites 0.004550355228734825
# diff per cation sites 0.00910071045746965
# -----------------------------------
# Reading d3_calcs/Cu10Sb3_2004/Cu10Sb3_2004.csv
# Composition Cu20 Sb6
# diff per toal sites 0.0077576123469795776
# diff per cation sites 0.01008489605107345
# -----------------------------------
# Reading d3_calcs/Na3Cu_1186036/Na3Cu_1186036.csv
# Composition Na3 Cu1
# diff per toal sites 0.010895489954391213
# diff per cation sites 0.04358195981756485
# -----------------------------------
# Reading d3_calcs/In3Cu7_21985/In3Cu7_21985.csv
# Composition In12 Cu28
# diff per toal sites 0.010729110974567437
# diff per cation sites 0.015327301392239196
# -----------------------------------
# Reading d3_calcs/In2Cu_1018730/In2Cu_1018730.csv
# Composition In4 Cu2
# diff per toal sites 0.0077236965702486005
# diff per cation sites 0.0231710897107458
# -----------------------------------
# Reading d3_calcs/Cu11Sb3_30596/Cu11Sb3_30596.csv
# Composition Cu11 Sb3
# diff per toal sites 0.007966734214848678
# diff per cation sites 0.01013947990980741
# -----------------------------------
# Reading d3_calcs/GaCu3_865798/GaCu3_865798.csv
# Composition Ga2 Cu6
# diff per toal sites 0.011938996166995123
# diff per cation sites 0.0159186615559935
# -----------------------------------
# Reading d3_calcs/Cu3Rh_1184028/Cu3Rh_1184028.csv
# Composition Cu3 Rh1
# diff per toal sites 0.015999615744165863
# diff per cation sites 0.02133282099222115
# -----------------------------------
# Reading d3_calcs/CuN6_608366/CuN6_608366.csv
# No local max found
# No local min found
# Composition Cu4 N24
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/Mg7Cu_1016285/Mg7Cu_1016285.csv
# Composition Mg7 Cu1
# diff per toal sites 0.01130901638934417
# diff per cation sites 0.09047213111475336
# -----------------------------------
# Reading d3_calcs/Cu5Sn4_568524/Cu5Sn4_568524.csv
# Composition Cu15 Sn12
# diff per toal sites 0.007455872243048963
# diff per cation sites 0.013420570037488134
# -----------------------------------
# Reading d3_calcs/CuS_1096941/CuS_1096941.csv
# Composition Cu1 S1
# diff per toal sites 0.0012344921566812975
# diff per cation sites 0.002468984313362595
# -----------------------------------
# Reading d3_calcs/Cu5Ge2_1225769/Cu5Ge2_1225769.csv
# Composition Cu5 Ge2
# diff per toal sites 0.007915971004913107
# diff per cation sites 0.01108235940687835
# -----------------------------------
# Reading d3_calcs/CuCl2_1238872/CuCl2_1238872.csv
# Composition Cu1 Cl2
# diff per toal sites 0.0013818540578154348
# diff per cation sites 0.004145562173446304
# -----------------------------------
# Reading d3_calcs/CuS_558139/CuS_558139.csv
# Composition Cu2 S2
# diff per toal sites 0.003800829418007937
# diff per cation sites 0.007601658836015874
# -----------------------------------
# Reading d3_calcs/Be3Cu_1183404/Be3Cu_1183404.csv
# Composition Be3 Cu1
# diff per toal sites 0.008575429219848187
# diff per cation sites 0.03430171687939275
# -----------------------------------
# Reading d3_calcs/Np3Cu_1186160/Np3Cu_1186160.csv
# Composition Np3 Cu1
# diff per toal sites 0.009971809438416749
# diff per cation sites 0.039887237753666996
# -----------------------------------
# Reading d3_calcs/CuCl2_1147756/CuCl2_1147756.csv
# Composition Cu1 Cl2
# diff per toal sites 0.0006333319389381719
# diff per cation sites 0.0018999958168145156
# -----------------------------------
# Reading d3_calcs/Cu2N_1147700/Cu2N_1147700.csv
# Composition Cu2 N1
# diff per toal sites 0.004718292478643449
# diff per cation sites 0.007077438717965174
# -----------------------------------
# Reading d3_calcs/CuRh_1225704/CuRh_1225704.csv
# Composition Cu1 Rh1
# diff per toal sites 0.020614576953691476
# diff per cation sites 0.04122915390738295
# -----------------------------------
# Reading d3_calcs/CdCu2_568315/CdCu2_568315.csv
# Composition Cd8 Cu16
# diff per toal sites 0.00904902516809448
# diff per cation sites 0.01357353775214172
# -----------------------------------
# Reading d3_calcs/ZrCu_2018976/ZrCu_2018976.csv
# Composition Zr2 Cu2
# diff per toal sites 0.0039977998609194
# diff per cation sites 0.0079955997218388
# -----------------------------------
# Reading d3_calcs/Cu2S_12087/Cu2S_12087.csv
# Composition Cu2 S1
# diff per toal sites 0.0046206652426675834
# diff per cation sites 0.006930997864001375
# -----------------------------------
# Reading d3_calcs/InCu2_12118/InCu2_12118.csv
# Composition In2 Cu4
# diff per toal sites 0.009552431522929025
# diff per cation sites 0.014328647284393536
# -----------------------------------
# Reading d3_calcs/CuBr_570354/CuBr_570354.csv
# Composition Cu1 Br1
# diff per toal sites 0.002934151640617068
# diff per cation sites 0.005868303281234136
# -----------------------------------
# Reading d3_calcs/CuAu4_1225742/CuAu4_1225742.csv
# No local max found
# No local min found
# Composition Cu1 Au4
# diff per toal sites 0.0
# diff per cation sites 0.0
# -----------------------------------
# Reading d3_calcs/Cu19Sn16_1225980/Cu19Sn16_1225980.csv
# Composition Cu19 Sn16
# diff per toal sites 0.007135663723661214
# diff per cation sites 0.013144643701481183
# -----------------------------------
# Reading d3_calcs/Cu9Se5_673655/Cu9Se5_673655.csv
# Composition Cu18 Se10
# diff per toal sites 0.00466482612073475
# diff per cation sites 0.00725639618780961
# -----------------------------------
# Reading d3_calcs/Cu7Si2_1206157/Cu7Si2_1206157.csv
# Composition Cu7 Si2
# diff per toal sites 0.008673990284916257
# diff per cation sites 0.011152273223463757
# -----------------------------------
# Reading d3_calcs/CuCl2_1147758/CuCl2_1147758.csv
# Composition Cu1 Cl2
# diff per toal sites 0.000650528911030895
# diff per cation sites 0.001951586733092685
# -----------------------------------
# Reading d3_calcs/Cu2As3_1245668/Cu2As3_1245668.csv
# Composition Cu2 As3
# diff per toal sites 0.00381053606827389
# diff per cation sites 0.009526340170684724
# -----------------------------------
# Reading d3_calcs/Co3Cu_1183752/Co3Cu_1183752.csv
# Composition Co3 Cu1
# diff per toal sites 0.0035040812141185745
# diff per cation sites 0.014016324856474298
# -----------------------------------
# Reading d3_calcs/Cu9Se8_936248/Cu9Se8_936248.csv
# Composition Cu9 Se8
# diff per toal sites 0.002607384627651462
# diff per cation sites 0.0049250598522305395
# -----------------------------------
# Reading d3_calcs/AlCu3_12777/AlCu3_12777.csv
# Composition Al1 Cu3
# diff per toal sites 0.009991910204699174
# diff per cation sites 0.013322546939598898
# -----------------------------------
# Reading d3_calcs/CuBr_22917/CuBr_22917.csv
# Composition Cu2 Br2
# diff per toal sites 0.0024772371445137002
# diff per cation sites 0.0049544742890274005
# -----------------------------------
# Reading d3_calcs/Li3Cu_975882/Li3Cu_975882.csv
# Composition Li3 Cu1
# diff per toal sites 0.017449007426023625
# diff per cation sites 0.0697960297040945
# -----------------------------------
# Reading d3_calcs/Cu8O7_1147761/Cu8O7_1147761.csv
# Composition Cu8 O7
# diff per toal sites 0.004528297796461026
# diff per cation sites 0.008490558368364425
# -----------------------------------
# Reading d3_calcs/CuO_1120722/CuO_1120722.csv
# Composition Cu3 O3
# diff per toal sites 0.0029142031828885743
# diff per cation sites 0.0058284063657771485
# -----------------------------------
# Reading d3_calcs/CuO2_2933735/CuO2_2933735.csv
# Composition Cu2 O4
# diff per toal sites 0.00036771844391719164
# diff per cation sites 0.001103155331751575
# -----------------------------------
# Reading d3_calcs/CuAs2_1245811/CuAs2_1245811.csv
# Composition Cu1 As2
# diff per toal sites 0.003494709329680667
# diff per cation sites 0.010484127989042
# -----------------------------------
# Reading d3_calcs/Tl3Cu_1187519/Tl3Cu_1187519.csv
# Composition Tl3 Cu1
# diff per toal sites 0.008012415533332089
# diff per cation sites 0.032049662133328355
# -----------------------------------
# Reading d3_calcs/HoCu5_580364/HoCu5_580364.csv
# Composition Ho1 Cu5
# diff per toal sites 0.01213720237839884
# diff per cation sites 0.014564642854078607
# -----------------------------------
# Reading d3_calcs/Cu2O3_1046820/Cu2O3_1046820.csv
# Composition Cu8 O12
# diff per toal sites 0.001880005929662875
# diff per cation sites 0.0047000148241571876
# -----------------------------------
# Reading d3_calcs/Cu4Au_1225761/Cu4Au_1225761.csv
# Composition Cu4 Au1
# diff per toal sites 0.00909155110247592
# diff per cation sites 0.0113644388780949
# -----------------------------------
# Reading d3_calcs/Cu3Sb_2002/Cu3Sb_2002.csv
# Composition Cu3 Sb1
# diff per toal sites 0.007676539331261138
# diff per cation sites 0.01023538577501485
# -----------------------------------
# Reading d3_calcs/CuNi3_1225694/CuNi3_1225694.csv
# Composition Cu1 Ni3
# diff per toal sites 0.003544137774035337
# diff per cation sites 0.014176551096141347
# -----------------------------------
# Reading d3_calcs/Cu2S_1394093/Cu2S_1394093.csv
# Composition Cu4 S2
# diff per toal sites 0.004913355524831108
# diff per cation sites 0.007370033287246662
# -----------------------------------
# Reading d3_calcs/Pm3Cu_1186511/Pm3Cu_1186511.csv
# Composition Pm3 Cu1
# diff per toal sites 0.02404916586758115
# diff per cation sites 0.0961966634703246
# -----------------------------------
# Reading d3_calcs/Cu3Si_972828/Cu3Si_972828.csv
# Composition Cu3 Si1
# diff per toal sites 0.008375117119656276
# diff per cation sites 0.011166822826208367
# -----------------------------------
# Reading d3_calcs/Cu8O7_760084/Cu8O7_760084.csv
# Composition Cu8 O7
# diff per toal sites 0.002398860439066023
# diff per cation sites 0.0044978633232487936
# -----------------------------------
# Reading d3_calcs/Fe3Cu_1225131/Fe3Cu_1225131.csv
# Composition Fe3 Cu1
# diff per toal sites 0.004949720311889288
# diff per cation sites 0.019798881247557153
# -----------------------------------
# Reading d3_calcs/CuF_10634/CuF_10634.csv
# Composition Cu1 F1
# diff per toal sites 0.002336210403286545
# diff per cation sites 0.00467242080657309
# -----------------------------------
# Reading d3_calcs/CuPb3_1184128/CuPb3_1184128.csv
# Composition Cu1 Pb3
# diff per toal sites 0.006084439347543301
# diff per cation sites 0.024337757390173204
# -----------------------------------
# Reading d3_calcs/Ti5Cu2_1208489/Ti5Cu2_1208489.csv
# Composition Ti20 Cu8
# diff per toal sites 0.019769561644865912
# diff per cation sites 0.0691934657570307
# -----------------------------------
# Reading d3_calcs/LaCu6_30590/LaCu6_30590.csv
# Composition La4 Cu24
# diff per toal sites 0.010670227314603197
# diff per cation sites 0.01244859853370373
# -----------------------------------
# Reading d3_calcs/Cu3Sn_581786/Cu3Sn_581786.csv
# Composition Cu6 Sn2
# diff per toal sites 0.00952084358067775
# diff per cation sites 0.012694458107570333
# -----------------------------------
# Reading d3_calcs/Cu2Se_684525/Cu2Se_684525.csv
# Composition Cu8 Se4
# diff per toal sites 0.004144686727043296
# diff per cation sites 0.0062170300905649446
# -----------------------------------
# Reading d3_calcs/Cu3As_1184008/Cu3As_1184008.csv
# Composition Cu3 As1
# diff per toal sites 0.007751045734431637
# diff per cation sites 0.010334727645908849
# -----------------------------------
# Reading d3_calcs/GdCu_614455/GdCu_614455.csv
# Composition Gd1 Cu1
# diff per toal sites 0.0169716586746314
# diff per cation sites 0.0339433173492628
# -----------------------------------
# Reading d3_calcs/YCu_712/YCu_712.csv
# Composition Y1 Cu1
# diff per toal sites 0.0161707932734947
# diff per cation sites 0.0323415865469894
# -----------------------------------
# Reading d3_calcs/Cu39S20_685126/Cu39S20_685126.csv
# Composition Cu39 S20
# diff per toal sites 0.0043101458418325425
# diff per cation sites 0.006520477042772308
# -----------------------------------
# Reading d3_calcs/Cr3Cu_984711/Cr3Cu_984711.csv
# Composition Cr3 Cu1
# diff per toal sites 0.0077837139683798115
# diff per cation sites 0.031134855873519246
# -----------------------------------
# Reading d3_calcs/CuNi3_1184054/CuNi3_1184054.csv
# Composition Cu1 Ni3
# diff per toal sites 0.0033424224336743615
# diff per cation sites 0.013369689734697446
# -----------------------------------
# Reading d3_calcs/Pr3Cu_975642/Pr3Cu_975642.csv
# Composition Pr3 Cu1
# diff per toal sites 0.025084626441843824
# diff per cation sites 0.1003385057673753
# -----------------------------------
# Reading d3_calcs/CuAs_1246684/CuAs_1246684.csv
# Composition Cu5 As5
# diff per toal sites 0.005717760615143204
# diff per cation sites 0.011435521230286409
# -----------------------------------
# Reading d3_calcs/ZrCu5_30603/ZrCu5_30603.csv
# Composition Zr1 Cu5
# diff per toal sites 0.011281698967387158
# diff per cation sites 0.01353803876086459
# -----------------------------------
# Reading d3_calcs/MgCu_2672345/MgCu_2672345.csv
# Composition Mg2 Cu2
# diff per toal sites 0.01039577697293125
# diff per cation sites 0.0207915539458625
# -----------------------------------
# Reading d3_calcs/BaCu13_642/BaCu13_642.csv
# Composition Ba2 Cu26
# diff per toal sites 0.009823154787215302
# diff per cation sites 0.010578782078539555
# -----------------------------------
# Reading d3_calcs/Cu3Ru_1184026/Cu3Ru_1184026.csv
# Composition Cu6 Ru2
# diff per toal sites 0.008088109691290417
# diff per cation sites 0.010784146255053889
# -----------------------------------
# Reading d3_calcs/CuO2_504100/CuO2_504100.csv
# Composition Cu4 O8
# diff per toal sites 0.0012324917135190583
# diff per cation sites 0.003697475140557175
# -----------------------------------
# Reading d3_calcs/CuO2_1181499/CuO2_1181499.csv
# Composition Cu2 O4
# diff per toal sites 0.0013416805717228336
# diff per cation sites 0.004025041715168501
# -----------------------------------
# Reading d3_calcs/CuN_13117/CuN_13117.csv
# Composition Cu1 N1
# diff per toal sites 0.0023021605820889753
# diff per cation sites 0.0046043211641779505
# -----------------------------------
# Reading d3_calcs/Cu2Sb_1825/Cu2Sb_1825.csv
# Composition Cu4 Sb2
# diff per toal sites 0.00624910497375955
# diff per cation sites 0.009373657460639324
# -----------------------------------
# Reading d3_calcs/Cu2S_2014814/Cu2S_2014814.csv
# Composition Cu4 S2
# diff per toal sites 0.002769616887813116
# diff per cation sites 0.004154425331719674
# -----------------------------------
# Reading d3_calcs/Cu7Te4_624307/Cu7Te4_624307.csv
# Composition Cu14 Te8
# diff per toal sites 0.005222980960898113
# diff per cation sites 0.00820754150998275
# -----------------------------------
# Reading d3_calcs/CuCl_23287/CuCl_23287.csv
# Composition Cu8 Cl8
# diff per toal sites 0.002040790027676972
# diff per cation sites 0.004081580055353944
# -----------------------------------
# Reading d3_calcs/CuRu3_1184121/CuRu3_1184121.csv
# Composition Cu1 Ru3
# diff per toal sites 0.009711043870598112
# diff per cation sites 0.03884417548239245
# -----------------------------------
# Reading d3_calcs/Al3Cu_985825/Al3Cu_985825.csv
# Composition Al3 Cu1
# diff per toal sites 0.007294371179367212
# diff per cation sites 0.02917748471746885
# -----------------------------------
# Reading d3_calcs/ZrCu2_1072655/ZrCu2_1072655.csv
# Composition Zr2 Cu4
# diff per toal sites 0.013668602988157308
# diff per cation sites 0.020502904482235962
# -----------------------------------
# Reading d3_calcs/Al3Cu_1183161/Al3Cu_1183161.csv
# Composition Al3 Cu1
# diff per toal sites 0.0079930867296868
# diff per cation sites 0.0319723469187472
# -----------------------------------
# Reading d3_calcs/CuS_760381/CuS_760381.csv
# Composition Cu1 S1
# diff per toal sites 0.0020404266485279997
# diff per cation sites 0.004080853297055999
# -----------------------------------
# Reading d3_calcs/CuI_23306/CuI_23306.csv
# Composition Cu2 I2
# diff per toal sites 0.0017744372630706744
# diff per cation sites 0.003548874526141349
# -----------------------------------
# Reading d3_calcs/Zn3Cu_1215483/Zn3Cu_1215483.csv
# Composition Zn3 Cu1
# diff per toal sites 0.011053697347548738
# diff per cation sites 0.04421478939019495
# -----------------------------------
# total structure analysed = 401

# %% [markdown]
# ### for individual elements

# %%
file = "../Li_bulk/Li_fcc/Li_fcc.csv"
struct_file = '../Li_bulk/Li_fcc/POSCAR'

df = pd.read_csv(file)
print(f"Reading {file}")
struct = Structure.from_file(struct_file)
sites = struct.num_sites
# print(struct.composition['Li'])
li_sites = struct.composition['Li']

diff_energy = finding_diff(df)
print(f'Composition {struct.composition}')
print(f'diff per toal sites {diff_energy/sites}')
print(f'diff per Li sites {diff_energy/li_sites}')
print('-----------------------------------')
result = {
    "Symbol": struct.composition.elements[0] if struct.composition.elements[0].symbol != 'Zn' else struct.composition.elements[1],
    "Structure": struct.composition,
    "Total Sites": sites,
    "Li Sites": li_sites,
    "Diff Energy": diff_energy,
    "Diff per Total Sites": diff_energy/sites,
    "Diff per Li Sites": diff_energy/li_sites,
    "Composition": str(struct.composition)
}

result
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 file = "../Li_bulk/Li_fcc/Li_fcc.csv"
#       2 struct_file = '../Li_bulk/Li_fcc/POSCAR'
# ----> 4 df = pd.read_csv(file)
#       5 print(f"Reading {file}")
#       6 struct = Structure.from_file(struct_file)
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Li_bulk/Li_fcc/Li_fcc.csv'

# %%
results_df = pd.DataFrame(results)
results_df.to_csv("analysis_results.csv", index=False)

print(f"Total structures analysed = {cnt}")
# print("Results saved to analysis_results.csv")

results_df
# Out:
# Total structures analysed = 401
#     Symbol Structure  Total Sites  Cation Sites  Counter Ion Sites  \
# 0       Sb  (Cu, Sb)            8           6.0                2.0
# 1       Br  (Cu, Br)            4           2.0                2.0
# 2       Ti  (Ti, Cu)           24           8.0               16.0
# 3       Li  (Li, Cu)            8           6.0                2.0
# 4       Pt  (Cu, Pt)            4           1.0                3.0
# ..     ...       ...          ...           ...                ...
# 395     Zr  (Zr, Cu)            6           4.0                2.0
# 396     Al  (Al, Cu)            4           1.0                3.0
# 397      S   (Cu, S)            2           1.0                1.0
# 398      I   (Cu, I)            4           2.0                2.0
# 399     Zn  (Zn, Cu)            4           1.0                3.0
#
#      Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 0       0.067424              0.008428               0.011237
# 1       0.000000              0.000000               0.000000
# 2       0.414120              0.017255               0.051765
# 3       0.113950              0.014244               0.018992
# 4       0.013335              0.003334               0.013335
# ..           ...                   ...                    ...
# 395     0.082012              0.013669               0.020503
# 396     0.031972              0.007993               0.031972
# 397     0.004081              0.002040               0.004081
# 398     0.007098              0.001774               0.003549
# 399     0.044215              0.011054               0.044215
#
#      Diff per Counter Ion Sites Composition
# 0                      0.033712     Cu6 Sb2
# 1                      0.000000     Cu2 Br2
# 2                      0.025882    Ti16 Cu8
# 3                      0.056975     Li2 Cu6
# 4                      0.004445     Cu1 Pt3
# ..                          ...         ...
# 395                    0.041006     Zr2 Cu4
# 396                    0.010657     Al3 Cu1
# 397                    0.004081      Cu1 S1
# 398                    0.003549      Cu2 I2
# 399                    0.014738     Zn3 Cu1
#
# [400 rows x 10 columns]

# %% [markdown]
# ### Thougest part is to make the Feature functions data

# %%
props = pd.read_csv('../all_compounds/PubChemElements_all.csv')
polarisability = pd.read_csv('../elements_polarizability.csv')

props = props[['Symbol', 'AtomicMass','AtomicRadius','Electronegativity','IonizationEnergy','ElectronAffinity']]

# %%
all_props = []
cnt = 0
for items in li_d3s:
    # cnt+=1
    #get the path of each folder
    path = os.path.join("d3_calcs", items)
    # print(items)
    
    #ignore .DS_Store
    if items == ".DS_Store":
        continue
    file = os.path.join(path, f'{items}.csv')
    struct_file = os.path.join(path, 'POSCAR')


    struct = Structure.from_file(struct_file)
    sites = struct.num_sites

    vol_site = struct.volume/sites
    # print(density)

    # print(struct.composition.elements[1])

    elem = struct.composition.elements[0] if(struct.composition.elements[1].symbol == 'Cu')  else struct.composition.elements[1]

    print(elem)
    # print(elem.symbol == 'Ge')

    matched_row = props[props['Symbol'] == elem.symbol]
    elem_polarizability = polarisability[polarisability['Symbol'] == elem.symbol]

    space_group = struct.get_space_group_info()


    
    print(struct.composition.reduced_formula)
    # DiffPerLi = results_df[results_df['Symbol'] == elem.symbol]
    # matched_row.add('Polarizability', elem_polarizability['Polarizability'].values[0])
    matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
    matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
    matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
    # matched_row['TotalSites'] = results_df['Total Sites'][cnt]
    matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
    matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
    matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
    # matched_row['Diff per Li Sites'] = DiffPerLi['Diff per Li Sites'].values[0]
    matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
    matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
    matched_row['SpaceGroup'] = space_group[0]
    matched_row['SpaceGroupNumber'] = space_group[1]
    matched_row['Total Sites'] = sites

    matched_row["Reduced Formula"] = struct.composition.reduced_formula
    all_props.append(matched_row)

    cnt+=1

all_props_df = pd.concat(all_props, ignore_index=True)
# Out:
# Sb
# Cu3Sb
# Br
# CuBr
# Ti
# Ti2Cu
# Li
# LiCu3
# Pt
# CuPt3
# O
# Cu4O3
# Te
# CuTe
# In
# InCu
# O
# Cu2O3
# As
# Cu3As4
# Mg
# Mg3Cu
# I
# CuI
# S
# CuS2
# La
# LaCu4
# O
# CuO
# Se
# Cu17Se10
# Te
# Cu3Te2
# Gd
# GdCu6
# Zr
# Zr2Cu
# Tb
# Tb6Cu23
# F
# CuF2
# I
# Cu16I19
# S
# Cu2S
# F
# Cu3F
# Hf
# HfCu3
# Au
# CuAu3
# Pd
# Cu3Pd
# Te
# CuTe
# Mg
# Mg15Cu
# As
# Cu3As
# S
# CuS
# Mg
# MgCu3
# I
# Cu14I19
# N
# CuN
# Se
# Cu2Se
# Ni
# Cu3Ni
# Te
# CuTe2
# Se
# Cu9Se5
# Sc
# ScCu3
# Te
# Cu2Te
# Zr
# ZrCu
# In
# In3Cu
# Ga
# GaCu2
# Se
# Cu25Se26
# S
# CuS2
# N
# Cu3N
# Pd
# Cu4Pd
# Ce
# CeCu6
# I
# CuI
# Pd
# CuPd
# O
# CuO2
# N
# Cu10N3
# S
# Cu11S20
# Sb
# Cu3Sb
# Te
# CuTe
# Se
# Cu13Se8
# Zn
# ZnCu3
# Zn
# ZnCu2
# Fe
# Fe3Cu
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_28936/18892322.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula

# %%
all_props_df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Sb  121.760000         206.0               2.05             8.640
# 1       Br   79.900000         183.0               2.96            11.814
# 2       Ti   47.867000         187.0               1.54             6.828
# 3       Li    7.000000         182.0               0.98             5.392
# 4       Pt  195.080000         209.0               2.28             9.000
# ..     ...         ...           ...                ...               ...
# 395     Zr   91.220000         186.0               1.33             6.634
# 396     Al   26.981538         184.0               1.61             5.986
# 397      S   32.070000         180.0               2.58            10.360
# 398      I  126.904500         198.0               2.66            10.451
# 399     Zn   65.400000         139.0               1.65             9.394
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 0               1.070         43.0000           8.427943           11.237257
# 1               3.365         21.0000           0.000000            0.000000
# 2               0.079        100.0000          17.254982           51.764945
# 3               0.618        164.1125          14.243751           18.991667
# 4               2.128         48.0000           3.333707           13.334829
# ..                ...             ...                ...                 ...
# 395             0.426        112.0000          13.668603           20.502904
# 396             0.441         57.8000           7.993087           31.972347
# 397             2.077         19.4000           2.040427            4.080853
# 398             3.059         32.9000           1.774437            3.548875
# 399               NaN         38.6700          11.053697           44.214789
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 0       0.750000         0.250000                 0.033712
# 1       0.500000         0.500000                 0.000000
# 2       0.333333         0.333333                 0.051765
# 3       0.750000         0.750000                 0.018992
# 4       0.250000         0.750000                 0.004445
# ..           ...              ...                      ...
# 395     0.666667         0.666667                 0.020503
# 396     0.250000         0.250000                 0.031972
# 397     0.500000         0.500000                 0.004081
# 398     0.500000         0.500000                 0.003549
# 399     0.250000         0.250000                 0.044215
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 0                 0.000566  0.566474       Pmmn                59
# 1                 0.000000  0.000000   P6_3/mmc               194
# 2                 0.001102  1.102493      Fd-3m               227
# 3                 0.001231  1.230899   P6_3/mmc               194
# 4                 0.000023  0.022682       Cmmm                65
# ..                     ...       ...        ...               ...
# 395               0.000899  0.899482       Cmcm                63
# 396               0.000529  0.529100      Pm-3m               221
# 397               0.000119  0.118808      F-43m               216
# 398               0.000061  0.061496       R-3m               166
# 399               0.000789  0.788562       Cmmm                65
#
#      Total Sites Reduced Formula
# 0              8           Cu3Sb
# 1              4            CuBr
# 2             24           Ti2Cu
# 3              8           LiCu3
# 4              4           CuPt3
# ..           ...             ...
# 395            6           ZrCu2
# 396            4           Al3Cu
# 397            2             CuS
# 398            4             CuI
# 399            4           Zn3Cu
#
# [400 rows x 18 columns]

# %%
all_props_df.to_csv('all_props_new.csv', index=False)

# %%
# show me some graphs to analyze NaN values

import matplotlib.pyplot as plt
import seaborn as sns

# Example DataFrame with NaN values (replace this with your actual DataFrame)
# For demonstration, we're creating a DataFrame with some random missing values.
np.random.seed(42)
data = {
    'A': np.random.choice([1, 2, np.nan], size=100),
    'B': np.random.choice([3, 4, np.nan], size=100),
    'C': np.random.choice([5, 6, np.nan], size=100),
    'D': np.random.choice([7, 8, np.nan], size=100)
}
df = pd.DataFrame(data)

# -------------------------------
# Plot 1: Heatmap of Missing Values
# -------------------------------
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Heatmap of Missing Values")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# -------------------------------
# Plot 2: Bar Chart of Missing Values per Column
# -------------------------------
missing_counts = df.isnull().sum().sort_values(ascending=False)
plt.figure(figsize=(8, 5))
missing_counts.plot(kind="bar", color='salmon')
plt.ylabel("Number of missing values")
plt.xlabel("Columns")
plt.title("Missing Values Count per Column")
plt.show()

# %%
all_props_df.fillna(0, inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(all_props_df.isnull(), cbar=False, cmap="viridis")
plt.title("Heatmap of Missing Values")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %%
# all_props_df.to_csv('all_props_new.csv', index=False)
all_props_df = pd.read_csv('all_props.csv')

all_props_df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Zn       65.40         139.0               1.65             9.394
# 1       Zn       65.40         139.0               1.65             9.394
# 2       Zn       65.40         139.0               1.65             9.394
# 3       Zn       65.40         139.0               1.65             9.394
# 4       Zn       65.40         139.0               1.65             9.394
# ..     ...         ...           ...                ...               ...
# 159     Se       78.97         190.0               2.55             9.752
# 160      S       32.07         180.0               2.58            10.360
# 161     Te      127.60         206.0               2.10             9.010
# 162     Zn       65.40         139.0               1.65             9.394
# 163     Zn       65.40         139.0               1.65             9.394
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 0                 NaN           38.67           0.012687        0.038062
# 1                 NaN           38.67           0.008223        0.008855
# 2                 NaN           38.67           0.011320        0.016980
# 3                 NaN           38.67           0.009284        0.011140
# 4                 NaN           38.67           0.010972        0.029258
# ..                ...             ...                ...             ...
# 159             2.021           28.90           0.002714        0.005429
# 160             2.077           19.40           0.002662        0.005324
# 161             1.971           38.00           0.002715        0.005429
# 162               NaN           38.67           0.015521        0.023282
# 163               NaN           38.67           0.017877        0.035753
#
#      ZnSites  CounterIonSites  results_per_counter_ion
# 0        1.0              1.0                 0.038062
# 1       26.0             26.0                 0.008855
# 2        4.0              4.0                 0.016980
# 3       10.0             10.0                 0.011140
# 4        6.0              6.0                 0.029258
# ..       ...              ...                      ...
# 159      1.0              1.0                 0.005429
# 160     28.0             28.0                 0.005324
# 161      3.0              3.0                 0.005429
# 162      4.0              4.0                 0.023282
# 163      1.0              1.0                 0.035753
#
# [164 rows x 12 columns]
