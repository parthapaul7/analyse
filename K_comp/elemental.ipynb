# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('all_props_new.csv')

# %%
df['req'] = df['Volume']/df['Total Sites']
df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Tb  158.925350         221.0                NaN             5.864
# 1        S   32.070000         180.0               2.58            10.360
# 2       In  114.818000         193.0               1.78             5.786
# 3       Rb   85.468000         303.0               0.82             4.177
# 4       Pb  207.000000         202.0               2.33             7.417
# ..     ...         ...           ...                ...               ...
# 315      S   32.070000         180.0               2.58            10.360
# 316     Cs  132.905452         343.0               0.79             3.894
# 317     Bi  208.980400         207.0               2.02             7.289
# 318     Te  127.600000         206.0               2.10             9.010
# 319     Ba  137.330000         268.0               0.89             5.212
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 0                 NaN           170.0           4.337265            5.783021
# 1               2.077            19.4           7.813656           11.720483
# 2               0.300            65.0           5.070009           20.280035
# 3               0.468           319.8           2.107778            8.431112
# 4               0.360            57.0           5.568713           18.098316
# ..                ...             ...                ...                 ...
# 315             2.077            19.4           2.996255           10.486891
# 316             0.472           400.9          11.041731           14.722308
# 317             0.946            53.0           7.198462           12.957232
# 318             1.971            38.0           6.825826           13.651651
# 319               NaN           272.0          13.785359           18.380479
#
#      CationSites  ...  results_per_counter_ion  res_per_volm_per_site  \
# 0       0.750000  ...                 0.017349               0.000076
# 1       0.666667  ...                 0.023441               0.000264
# 2       0.250000  ...                 0.006760               0.000169
# 3       0.250000  ...                 0.002810               0.000023
# 4       0.307692  ...                 0.008044               0.000139
# ..           ...  ...                      ...                    ...
# 315     0.285714  ...                 0.004195               0.000097
# 316     0.750000  ...                 0.014722               0.000129
# 317     0.555556  ...                 0.016197               0.000168
# 318     0.500000  ...                 0.013652               0.000158
# 319     0.750000  ...                 0.055141               0.000195
#
#        Result  SpaceGroup SpaceGroupNumber  Total Sites       Volume      mid  \
# 0    0.075517    P6_3/mmc              194            8   459.471608  1185125
# 1    0.263950    P6_3/mmc              194            6   177.616848   559278
# 2    0.169398       Fm-3m              225            4   119.718038  1185104
# 3    0.023148       Pm-3m              221            4   364.221518  1185080
# 4    0.138729      P2_1/m               11           52  2087.328498   680443
# ..        ...         ...              ...          ...          ...      ...
# 315  0.096999  P2_12_12_1               19           28   864.909095   672372
# 316  0.129397       Fm-3m              225            4   341.328208  1185554
# 317  0.167848          Cm                8            9   385.981993  1223773
# 318  0.157881       P-62m              189           12   518.806543     1554
# 319  0.194621      I4/mmm              139            4   283.327375  1184910
#
#      Reduced Formula        req
# 0               K3Tb  57.433951
# 1                K2S  29.602808
# 2               KIn3  29.929509
# 3               KRb3  91.055379
# 4              K4Pb9  40.140933
# ..               ...        ...
# 315             K2S5  30.889611
# 316             CsK3  85.332052
# 317            K5Bi4  42.886888
# 318              KTe  43.233879
# 319             K3Ba  70.831844
#
# [320 rows x 21 columns]

# %%
df['results_per_total'] = df['results_per_total'] * 27.2114 / 1000

# %%
element = 'C'
comp = 'KO2'

# %%
grouped_df = df.groupby('Symbol')
oxy_group = pd.DataFrame()
for symbol, group in grouped_df:
    # print(f"Category: {symbol}")
    # print(group['Result'].max())
    # print(group['Result'].min())
    if symbol == element:
        # print(group['Result'])
        # print('---------------------')
        # print((group['Result'].max() - group['Result'].min())/group['Result'].mean() * 100)
        # print(group)
        oxy_group  = group
    # if(symbol == 'Al'):
    #     print(group)
    # print("\n")


# grouped_df = oxy_group.groupby('Reduced Formula')
# oxy_group = pd.DataFrame()
# for Form, group in grouped_df:

#     if Form == comp:
#         oxy_group = group

oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 29       C      12.011         170.0               2.55             11.26
# 55       C      12.011         170.0               2.55             11.26
# 91       C      12.011         170.0               2.55             11.26
# 104      C      12.011         170.0               2.55             11.26
# 117      C      12.011         170.0               2.55             11.26
# 171      C      12.011         170.0               2.55             11.26
# 226      C      12.011         170.0               2.55             11.26
# 230      C      12.011         170.0               2.55             11.26
# 249      C      12.011         170.0               2.55             11.26
# 251      C      12.011         170.0               2.55             11.26
# 266      C      12.011         170.0               2.55             11.26
# 275      C      12.011         170.0               2.55             11.26
# 306      C      12.011         170.0               2.55             11.26
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 29              1.263            11.3           0.033373            3.679271
# 55              1.263            11.3           0.042954            3.157094
# 91              1.263            11.3           0.035522            3.916177
# 104             1.263            11.3           0.027023           10.923958
# 117             1.263            11.3           0.130988           14.441170
# 171             1.263            11.3           0.042966            3.157959
# 226             1.263            11.3           0.033965            3.744623
# 230             1.263            11.3           0.012433           27.870985
# 249             1.263            11.3           0.035991            2.645310
# 251             1.263            11.3           0.035516            3.915571
# 266             1.263            11.3           0.209984            9.645942
# 275             1.263            11.3           0.035789            1.972858
# 306             1.263            11.3           0.043196            3.174816
#
#      CationSites  ...  results_per_counter_ion  res_per_volm_per_site  \
# 29      0.333333  ...                 0.001840               0.000051
# 55      0.500000  ...                 0.003157               0.000054
# 91      0.333333  ...                 0.001958               0.000055
# 104     0.090909  ...                 0.001092               0.000085
# 117     0.333333  ...                 0.007221               0.000193
# 171     0.500000  ...                 0.003158               0.000054
# 226     0.333333  ...                 0.001872               0.000052
# 230     0.016393  ...                 0.000465               0.000042
# 249     0.500000  ...                 0.002645               0.000049
# 251     0.333333  ...                 0.001958               0.000055
# 266     0.800000  ...                 0.038584               0.000167
# 275     0.666667  ...                 0.003946               0.000042
# 306     0.500000  ...                 0.003175               0.000054
#
#        Result  SpaceGroup SpaceGroupNumber  Total Sites       Volume      mid  \
# 29   0.051140        C2/m               12            6   143.890629  1211583
# 55   0.053715        C2/c               15            4   117.550244  1064300
# 91   0.054744      I4/mmm              139            3    71.536242  2285616
# 104  0.085288        Im-3              204           66   768.500015    16791
# 117  0.193380        Immm               71            3    74.677738  1211615
# 171  0.053661        C2/m               12            4   117.699310  1064814
# 226  0.052104        C2/c               15            6   143.735577  1211632
# 230  0.041934        Pnnm               58          122  1329.286471    29687
# 249  0.049133    I4_1/acd              142           16   430.718916      243
# 251  0.054735      P4/nmm              129            6   143.072503  1072274
# 266  0.167037      I4/mmm              139            5   230.989406  1206408
# 275  0.042388       Fm-3m              225            3    93.086367  1211945
# 306  0.053675       Fm-3m              225            2    59.149103   722819
#
#      Reduced Formula        req
# 29               KC2  23.981771
# 55                KC  29.387561
# 91               KC2  23.845414
# 104             KC10  11.643940
# 117              KC2  24.892579
# 171               KC  29.424828
# 226              KC2  23.955930
# 230             KC60  10.895791
# 249               KC  26.919932
# 251              KC2  23.845417
# 266              K4C  46.197881
# 275              K2C  31.028789
# 306               KC  29.574552
#
# [13 rows x 21 columns]

# %%
subset_80 = oxy_group.sort_values(by='req')
# subset_80 = subset_80[subset_80['req']  > 17]
subset_80
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 230      C      12.011         170.0               2.55             11.26
# 104      C      12.011         170.0               2.55             11.26
# 91       C      12.011         170.0               2.55             11.26
# 251      C      12.011         170.0               2.55             11.26
# 226      C      12.011         170.0               2.55             11.26
# 29       C      12.011         170.0               2.55             11.26
# 117      C      12.011         170.0               2.55             11.26
# 249      C      12.011         170.0               2.55             11.26
# 55       C      12.011         170.0               2.55             11.26
# 171      C      12.011         170.0               2.55             11.26
# 306      C      12.011         170.0               2.55             11.26
# 275      C      12.011         170.0               2.55             11.26
# 266      C      12.011         170.0               2.55             11.26
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 230             1.263            11.3           0.012433           27.870985
# 104             1.263            11.3           0.027023           10.923958
# 91              1.263            11.3           0.035522            3.916177
# 251             1.263            11.3           0.035516            3.915571
# 226             1.263            11.3           0.033965            3.744623
# 29              1.263            11.3           0.033373            3.679271
# 117             1.263            11.3           0.130988           14.441170
# 249             1.263            11.3           0.035991            2.645310
# 55              1.263            11.3           0.042954            3.157094
# 171             1.263            11.3           0.042966            3.157959
# 306             1.263            11.3           0.043196            3.174816
# 275             1.263            11.3           0.035789            1.972858
# 266             1.263            11.3           0.209984            9.645942
#
#      CationSites  ...  results_per_counter_ion  res_per_volm_per_site  \
# 230     0.016393  ...                 0.000465               0.000042
# 104     0.090909  ...                 0.001092               0.000085
# 91      0.333333  ...                 0.001958               0.000055
# 251     0.333333  ...                 0.001958               0.000055
# 226     0.333333  ...                 0.001872               0.000052
# 29      0.333333  ...                 0.001840               0.000051
# 117     0.333333  ...                 0.007221               0.000193
# 249     0.500000  ...                 0.002645               0.000049
# 55      0.500000  ...                 0.003157               0.000054
# 171     0.500000  ...                 0.003158               0.000054
# 306     0.500000  ...                 0.003175               0.000054
# 275     0.666667  ...                 0.003946               0.000042
# 266     0.800000  ...                 0.038584               0.000167
#
#        Result  SpaceGroup SpaceGroupNumber  Total Sites       Volume      mid  \
# 230  0.041934        Pnnm               58          122  1329.286471    29687
# 104  0.085288        Im-3              204           66   768.500015    16791
# 91   0.054744      I4/mmm              139            3    71.536242  2285616
# 251  0.054735      P4/nmm              129            6   143.072503  1072274
# 226  0.052104        C2/c               15            6   143.735577  1211632
# 29   0.051140        C2/m               12            6   143.890629  1211583
# 117  0.193380        Immm               71            3    74.677738  1211615
# 249  0.049133    I4_1/acd              142           16   430.718916      243
# 55   0.053715        C2/c               15            4   117.550244  1064300
# 171  0.053661        C2/m               12            4   117.699310  1064814
# 306  0.053675       Fm-3m              225            2    59.149103   722819
# 275  0.042388       Fm-3m              225            3    93.086367  1211945
# 266  0.167037      I4/mmm              139            5   230.989406  1206408
#
#      Reduced Formula        req
# 230             KC60  10.895791
# 104             KC10  11.643940
# 91               KC2  23.845414
# 251              KC2  23.845417
# 226              KC2  23.955930
# 29               KC2  23.981771
# 117              KC2  24.892579
# 249               KC  26.919932
# 55                KC  29.387561
# 171               KC  29.424828
# 306               KC  29.574552
# 275              K2C  31.028789
# 266              K4C  46.197881
#
# [13 rows x 21 columns]

# %%
x = subset_80['req']
y = subset_80['results_per_total']
plt.figure(figsize=(10, 6))
m, b = np.polyfit(x, y, 1)  # linear fit
plt.scatter(x, y, alpha=1, s=100, color='blue')
# plt.plot(x, m*x + b, color='red')
# plt.show()
plt.xlabel('Volume per unit atom', fontsize=18)
plt.ylabel('Error Per unit atom (mEh)', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
res = pd.read_csv('analysis_results.csv')

# %%
res = res[res['Symbol'] == element]
res
# Out:
#     Symbol Structure  Total Sites  Cation Sites  Counter Ion Sites  \
# 29       C     K2 C4            6           2.0                4.0
# 55       C     K2 C2            4           2.0                2.0
# 91       C     K1 C2            3           1.0                2.0
# 104      C    K6 C60           66           6.0               60.0
# 117      C     K1 C2            3           1.0                2.0
# 171      C     K2 C2            4           2.0                2.0
# 226      C     K2 C4            6           2.0                4.0
# 230      C   K2 C120          122           2.0              120.0
# 249      C     K8 C8           16           8.0                8.0
# 251      C     K2 C4            6           2.0                4.0
# 266      C     K4 C1            5           4.0                1.0
# 275      C     K2 C1            3           2.0                1.0
# 306      C     K1 C1            2           1.0                1.0
#
#      Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 29      0.007359              0.001226               0.003679
# 55      0.006314              0.001579               0.003157
# 91      0.003916              0.001305               0.003916
# 104     0.065544              0.000993               0.010924
# 117     0.014441              0.004814               0.014441
# 171     0.006316              0.001579               0.003158
# 226     0.007489              0.001248               0.003745
# 230     0.055742              0.000457               0.027871
# 249     0.021162              0.001323               0.002645
# 251     0.007831              0.001305               0.003916
# 266     0.038584              0.007717               0.009646
# 275     0.003946              0.001315               0.001973
# 306     0.003175              0.001587               0.003175
#
#      Diff per Counter Ion Sites       Volume      mid Composition
# 29                     0.001840   143.890629  1211583       K2 C4
# 55                     0.003157   117.550244  1064300       K2 C2
# 91                     0.001958    71.536242  2285616       K1 C2
# 104                    0.001092   768.500015    16791      K6 C60
# 117                    0.007221    74.677738  1211615       K1 C2
# 171                    0.003158   117.699310  1064814       K2 C2
# 226                    0.001872   143.735577  1211632       K2 C4
# 230                    0.000465  1329.286471    29687     K2 C120
# 249                    0.002645   430.718916      243       K8 C8
# 251                    0.001958   143.072503  1072274       K2 C4
# 266                    0.038584   230.989406  1206408       K4 C1
# 275                    0.003946    93.086367  1211945       K2 C1
# 306                    0.003175    59.149103   722819       K1 C1

# %%
# oxy_group = oxy_group.sample(frac=0.5, random_state=39)

# %%
oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 29       C      12.011         170.0               2.55             11.26
# 55       C      12.011         170.0               2.55             11.26
# 91       C      12.011         170.0               2.55             11.26
# 104      C      12.011         170.0               2.55             11.26
# 117      C      12.011         170.0               2.55             11.26
# 171      C      12.011         170.0               2.55             11.26
# 226      C      12.011         170.0               2.55             11.26
# 230      C      12.011         170.0               2.55             11.26
# 249      C      12.011         170.0               2.55             11.26
# 251      C      12.011         170.0               2.55             11.26
# 266      C      12.011         170.0               2.55             11.26
# 275      C      12.011         170.0               2.55             11.26
# 306      C      12.011         170.0               2.55             11.26
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 29              1.263            11.3           0.033373            3.679271
# 55              1.263            11.3           0.042954            3.157094
# 91              1.263            11.3           0.035522            3.916177
# 104             1.263            11.3           0.027023           10.923958
# 117             1.263            11.3           0.130988           14.441170
# 171             1.263            11.3           0.042966            3.157959
# 226             1.263            11.3           0.033965            3.744623
# 230             1.263            11.3           0.012433           27.870985
# 249             1.263            11.3           0.035991            2.645310
# 251             1.263            11.3           0.035516            3.915571
# 266             1.263            11.3           0.209984            9.645942
# 275             1.263            11.3           0.035789            1.972858
# 306             1.263            11.3           0.043196            3.174816
#
#      CationSites  ...  results_per_counter_ion  res_per_volm_per_site  \
# 29      0.333333  ...                 0.001840               0.000051
# 55      0.500000  ...                 0.003157               0.000054
# 91      0.333333  ...                 0.001958               0.000055
# 104     0.090909  ...                 0.001092               0.000085
# 117     0.333333  ...                 0.007221               0.000193
# 171     0.500000  ...                 0.003158               0.000054
# 226     0.333333  ...                 0.001872               0.000052
# 230     0.016393  ...                 0.000465               0.000042
# 249     0.500000  ...                 0.002645               0.000049
# 251     0.333333  ...                 0.001958               0.000055
# 266     0.800000  ...                 0.038584               0.000167
# 275     0.666667  ...                 0.003946               0.000042
# 306     0.500000  ...                 0.003175               0.000054
#
#        Result  SpaceGroup SpaceGroupNumber  Total Sites       Volume      mid  \
# 29   0.051140        C2/m               12            6   143.890629  1211583
# 55   0.053715        C2/c               15            4   117.550244  1064300
# 91   0.054744      I4/mmm              139            3    71.536242  2285616
# 104  0.085288        Im-3              204           66   768.500015    16791
# 117  0.193380        Immm               71            3    74.677738  1211615
# 171  0.053661        C2/m               12            4   117.699310  1064814
# 226  0.052104        C2/c               15            6   143.735577  1211632
# 230  0.041934        Pnnm               58          122  1329.286471    29687
# 249  0.049133    I4_1/acd              142           16   430.718916      243
# 251  0.054735      P4/nmm              129            6   143.072503  1072274
# 266  0.167037      I4/mmm              139            5   230.989406  1206408
# 275  0.042388       Fm-3m              225            3    93.086367  1211945
# 306  0.053675       Fm-3m              225            2    59.149103   722819
#
#      Reduced Formula        req
# 29               KC2  23.981771
# 55                KC  29.387561
# 91               KC2  23.845414
# 104             KC10  11.643940
# 117              KC2  24.892579
# 171               KC  29.424828
# 226              KC2  23.955930
# 230             KC60  10.895791
# 249               KC  26.919932
# 251              KC2  23.845417
# 266              K4C  46.197881
# 275              K2C  31.028789
# 306               KC  29.574552
#
# [13 rows x 21 columns]

# %%
merged_df = pd.merge(res, oxy_group, left_index=True, right_index=True)
# merged_df.sort_values(by='Result',inplace=True, ascending=False)
# merged_df['SpaceGroup']

merged_df['Counter Ion Sites']
# Out:
# 29       4.0
# 55       2.0
# 91       2.0
# 104     60.0
# 117      2.0
# 171      2.0
# 226      4.0
# 230    120.0
# 249      8.0
# 251      4.0
# 266      1.0
# 275      1.0
# 306      1.0
# Name: Counter Ion Sites, dtype: float64

# %%
merged_df.rename(columns={"results_per_total": "Result_1"}, inplace=True)
# merged_df['Total Sites_x']

# %%
merged_df.sort_values(by='Result_1',inplace=True, ascending=False)

# %%
symbol = merged_df['Symbol_x'].values[0]
symbol
# Out:
# 'C'

# %%
full_li = merged_df['Cation Sites']
merged_df['Anion Site'] = (merged_df['Counter Ion Sites'] / full_li).round(2)

merged_df.sort_values(by='Anion Site',inplace=False, ascending=False)
merged_df['Structure_SG'] = "K-" + symbol+(merged_df['Counter Ion Sites'] / full_li).round(2).astype(str)

# %%
merged_df.to_csv(f'chemical_space/K_{symbol}.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create combined x-axis label

full_li = merged_df['Cation Sites']
merged_df['Anion Site'] = (merged_df['Counter Ion Sites'] / full_li).round(2)

merged_df.sort_values(by=['Anion Site', 'Result_1'], inplace=True, ascending=[True, False])
merged_df['Structure_SG'] = "K-" + symbol+(merged_df['Counter Ion Sites'] / full_li).round(2).astype(str) 
# Set data
x_labels = merged_df['Structure_SG']
values = merged_df['Result_1']

# Create figure
plt.figure(figsize=(10, 6))

# Create bar plot
x = np.arange(len(x_labels))  # numeric x-axis positions
plt.bar(x, values, width=0.6)

# X-axis setup
plt.xticks(x, x_labels, rotation=60, ha='right',fontsize=14)

# plt.xlabel('Structure')
plt.ylabel('Energy (mEh)', fontsize=12)
# plt.title('Grouped Bar Plot of Result_1 by Structure and SpaceGroup')
# plt.legend(title='Metric')
plt.tight_layout()

# Save or show
plt.savefig(f'chemical_space/K_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
avg_electronegativity = merged_df['Electronegativity'].mean()
avg_polarizability = merged_df['Polarizability'].mean()
avg_result = merged_df['Result_1'].mean()

print("Average Electronegativity:", avg_electronegativity)
print("Average Polarizability:", avg_polarizability)
print("Average Result:", avg_result)
# Out:
# Average Electronegativity: 2.55
# Average Polarizability: 11.3
# Average Result: 0.05536160761062865

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- after you have merged_df ready ---

# 1. Build a display label with subscripted CN
def make_disp_label(sg):
    # sg is like "Li-C0.33" or "K-C1.0"
    metal, cn_str = sg.split(f'-{element}')  # ["Li", "0.33"]
    cn_str = f"{float(cn_str):.2f}"  # Ensure two decimal places
    # metal is "Li" or "K"; cn_str is "0.33", "1.0", etc.
    return rf"{cn_str}"
    return rf"$\mathrm{{{metal}{element}}}_{{{cn_str}}}$"

merged_df['DispLabel'] = merged_df['Structure_SG'].apply(make_disp_label)

# 2. Plot
x = np.arange(len(merged_df))
values = merged_df['Result_1']
labels = merged_df['DispLabel']

plt.figure(figsize=(16, 9))
plt.bar(x, values, width=0.6, color='teal')

# 3. Use the LaTeX labels
plt.xticks(x, labels, rotation=45, ha='right', fontsize=42)
plt.yticks(fontsize=42)
plt.ylabel('Energy (mEh)', fontsize=42, labelpad=20)
plt.xlabel(rf'$\mathrm{{K{symbol}_X}}$', fontsize=42)
# plt.subplots_adjust(top=15)

plt.tight_layout()
plt.savefig(f'chemical_space/k_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()
