# %%
import os
import numpy as np
import pandas as pd

import pymatgen as pg

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# %%
def local_min(df):

    df['dy'] = df['Edis'].diff()

    df['sign_dy'] = np.sign(df['dy'])
    df['sign_change'] = df['sign_dy'].diff()

    # Indices of local maxima: derivative goes from negative (-1) to positive (+1)
    local_min_indices = df.index[(df['sign_change'] > 0)]

    local_mins = df.loc[local_min_indices, ['cell_length', 'Edis']].reset_index(drop=True)

    return local_mins

def local_max(df):
    df['dy'] = df['Edis'].diff()

    df['sign_dy'] = np.sign(df['dy'])
    df['sign_change'] = df['sign_dy'].diff()

    # Indices of local maxima: derivative goes from negative (-1) to positive (+1)
    local_min_indices = df.index[(df['sign_change'] < 0)]

    local_max = df.loc[local_min_indices, ['cell_length', 'Edis']].reset_index(drop=True)

    return local_max

# %%
def finding_diff(df):
    abs_max = df['Edis'].max()
    max_val = local_max(df)
    min_val = local_min(df)

    diff = (abs_max + max_val['Edis'][0])/2 - min_val['Edis'][0]

    return diff

# %%
from pymatgen.core import Structure

# %%
#list all folders inside li_d3s
li_d3s = os.listdir("li_d3s")

results = []

df = pd.DataFrame()
cnt=0
for items in li_d3s:
    cnt+=1
    #get the path of each folder
    path = os.path.join("li_d3s", items)
    # print(items)
    
    #ignore .DS_Store
    if items == ".DS_Store":
        continue
    file = os.path.join(path, f'{items}.csv')
    struct_file = os.path.join(path, 'POSCAR')
    df = pd.read_csv(file)
    print(f"Reading {file}")

    struct = Structure.from_file(struct_file)
    sites = struct.num_sites

    # print(struct.composition['Li'])
    li_sites = struct.composition['Li']
    counter_ion_sites = struct.composition[struct.composition.elements[1]] if struct.composition.elements[0].symbol == 'Li' else struct.composition[struct.composition.elements[0]]
   
    diff_energy = finding_diff(df)
    # print(f'Composition {struct.composition}')
    # print(f'diff per toal sites {diff_energy/sites}')
    # print(f'diff per Li sites {diff_energy/li_sites}')
    # print('-----------------------------------')

    # if counter_ion_sites == 0:

    result = {
        "Symbol": struct.composition.elements[1] if struct.composition.elements[0].symbol == 'Li' else struct.composition.elements[0],
        "Structure": struct.composition,
        "Total Sites": sites,
        "Li Sites": li_sites,
        "Counter Ion Sites": counter_ion_sites,
        "Diff Energy": diff_energy,
        "Diff per Total Sites": diff_energy/sites,
        "Diff per Li Sites": diff_energy/li_sites,
        "Diff per Counter Ion Sites": diff_energy/counter_ion_sites,
        "Composition": str(struct.composition)
    }

    results.append(result)
print(f'total structure analysed = {cnt}')
# Out:
# Reading li_d3s/LiGa3_1185332/LiGa3_1185332.csv
# Reading li_d3s/LiCu3_1185338/LiCu3_1185338.csv
# Reading li_d3s/LiAg_2426/LiAg_2426.csv
# Reading li_d3s/Li3Pd_11489/Li3Pd_11489.csv
# Reading li_d3s/Li3In_976055/Li3In_976055.csv
# Reading li_d3s/LiPr3_1185406/LiPr3_1185406.csv
# Reading li_d3s/LiMg_976244/LiMg_976244.csv
# Reading li_d3s/LiCe3_1185343/LiCe3_1185343.csv
# Reading li_d3s/Li27Sb10_676024/Li27Sb10_676024.csv
# Reading li_d3s/Li2Cd_1210799/Li2Cd_1210799.csv
# Reading li_d3s/Li3Al2_16506/Li3Al2_16506.csv
# Reading li_d3s/Li3P_736/Li3P_736.csv
# Reading li_d3s/NaLi3_1186151/NaLi3_1186151.csv
# Reading li_d3s/Li2Al_1210792/Li2Al_1210792.csv
# Reading li_d3s/Li2S_1153/Li2S_1153.csv
# Reading li_d3s/LiMg3_1094596/LiMg3_1094596.csv
# Reading li_d3s/Li3Tc_977230/Li3Tc_977230.csv
# Reading li_d3s/Li3Ca_976075/Li3Ca_976075.csv
# Reading li_d3s/LiIn3_863027/LiIn3_863027.csv
# Reading li_d3s/Li7Si2_27930/Li7Si2_27930.csv
# Reading li_d3s/Rb3Li_974959/Rb3Li_974959.csv
# Reading li_d3s/K3Li_1184918/K3Li_1184918.csv
# Reading li_d3s/Li10Pb3_504760/Li10Pb3_504760.csv
# Reading li_d3s/Li2Mg_1094586/Li2Mg_1094586.csv
# Reading li_d3s/Li5In4_1079408/Li5In4_1079408.csv
# Reading li_d3s/LiAu_1222403/LiAu_1222403.csv
# Reading li_d3s/Li3N_2251/Li3N_2251.csv
# Reading li_d3s/LiIn3_973748/LiIn3_973748.csv
# Reading li_d3s/LiMg_976239/LiMg_976239.csv
# Reading li_d3s/LiO8_1235059/LiO8_1235059.csv
# Reading li_d3s/LiNp3_1185274/LiNp3_1185274.csv
# Reading li_d3s/Li2B_1222698/Li2B_1222698.csv
# Reading li_d3s/LiCd_1437/LiCd_1437.csv
# Reading li_d3s/LiP3_1025406/LiP3_1025406.csv
# Reading li_d3s/Li3Au_1185200/Li3Au_1185200.csv
# Reading li_d3s/LiTl_934/LiTl_934.csv
# Reading li_d3s/Li7Sn3_30768/Li7Sn3_30768.csv
# Reading li_d3s/Li7Pb2_30761/Li7Pb2_30761.csv
# Reading li_d3s/LiMg_1094578/LiMg_1094578.csv
# Reading li_d3s/LiO2_1018789/LiO2_1018789.csv
# Reading li_d3s/LiH_23703/LiH_23703.csv
# Reading li_d3s/Li3Mg_976139/Li3Mg_976139.csv
# Reading li_d3s/LiW3_1185237/LiW3_1185237.csv
# Reading li_d3s/LiB9_1105976/LiB9_1105976.csv
# Reading li_d3s/LiP5_2412/LiP5_2412.csv
# Reading li_d3s/LiRe3_1185410/LiRe3_1185410.csv
# Reading li_d3s/LiMg2_1094604/LiMg2_1094604.csv
# Reading li_d3s/Li5Mg_976944/Li5Mg_976944.csv
# Reading li_d3s/Li3N2_1222421/Li3N2_1222421.csv
# Reading li_d3s/LiB3_1222413/LiB3_1222413.csv
# Reading li_d3s/Li3Pu_977299/Li3Pu_977299.csv
# Reading li_d3s/Li3Ge_867342/Li3Ge_867342.csv
# Reading li_d3s/LiO8_1235698/LiO8_1235698.csv
# Reading li_d3s/Li2Ga_29210/Li2Ga_29210.csv
# Reading li_d3s/LiBe_1001825/LiBe_1001825.csv
# Reading li_d3s/LiMg_976262/LiMg_976262.csv
# Reading li_d3s/Li3P7_28336/Li3P7_28336.csv
# Reading li_d3s/Li3Ag2_1222584/Li3Ag2_1222584.csv
# Reading li_d3s/Li2O_1245092/Li2O_1245092.csv
# Reading li_d3s/LiF_1138/LiF_1138.csv
# Reading li_d3s/Li3Cr_1185185/Li3Cr_1185185.csv
# Reading li_d3s/LiTl3_973191/LiTl3_973191.csv
# Reading li_d3s/LiPm3_1185395/LiPm3_1185395.csv
# Reading li_d3s/LiMg149_866755/LiMg149_866755.csv
# Reading li_d3s/Li3Pt_976322/Li3Pt_976322.csv
# Reading li_d3s/LiO8_1235252/LiO8_1235252.csv
# total structure analysed = 453

# %% [markdown]
# ### for individual elements

# %%
file = "../Li_bulk/Li_fcc/Li_fcc.csv"
struct_file = '../Li_bulk/Li_fcc/POSCAR'

df = pd.read_csv(file)
print(f"Reading {file}")
struct = Structure.from_file(struct_file)
sites = struct.num_sites
# print(struct.composition['Li'])
li_sites = struct.composition['Li']

diff_energy = finding_diff(df)
print(f'Composition {struct.composition}')
print(f'diff per toal sites {diff_energy/sites}')
print(f'diff per Li sites {diff_energy/li_sites}')
print('-----------------------------------')
result = {
    "Symbol": struct.composition.elements[0],
    "Structure": struct.composition,
    "Total Sites": sites,
    "Li Sites": li_sites,
    "Diff Energy": diff_energy,
    "Diff per Total Sites": diff_energy/sites,
    "Diff per Li Sites": diff_energy/li_sites,
    "Composition": str(struct.composition)
}

result
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 file = "../Li_bulk/Li_fcc/Li_fcc.csv"
#       2 struct_file = '../Li_bulk/Li_fcc/POSCAR'
# ----> 4 df = pd.read_csv(file)
#       5 print(f"Reading {file}")
#       6 struct = Structure.from_file(struct_file)
#
# File c:\Users\user\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\user\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\user\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\user\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\user\miniconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Li_bulk/Li_fcc/Li_fcc.csv'

# %%
results_df = pd.DataFrame(results)
results_df.to_csv("analysis_results.csv", index=False)

print(f"Total str.uctures analysed = {cnt}")
# print("Results saved to analysis_results.csv")

results_df
# Out:
# Total str.uctures analysed = 453
#     Symbol Structure  Total Sites  Li Sites  Counter Ion Sites  Diff Energy  \
# 0       Ga  (Li, Ga)            4       1.0                3.0     0.046840
# 1       Cu  (Li, Cu)            8       2.0                6.0     0.113950
# 2       Ag  (Li, Ag)            2       1.0                1.0     0.023085
# 3       Pd  (Li, Pd)            4       3.0                1.0     0.062838
# 4       In  (Li, In)            4       3.0                1.0     0.069164
# ..     ...       ...          ...       ...                ...          ...
# 447     Tl  (Li, Tl)            4       1.0                3.0     0.042584
# 448     Pm  (Li, Pm)            4       1.0                3.0     0.125808
# 449     Mg  (Li, Mg)          150       1.0              149.0     1.516943
# 450     Pt  (Li, Pt)            4       3.0                1.0     0.056048
# 451      O   (Li, O)            9       1.0                8.0     0.006780
#
#      Diff per Total Sites  Diff per Li Sites  Diff per Counter Ion Sites  \
# 0                0.011710           0.046840                    0.015613
# 1                0.014244           0.056975                    0.018992
# 2                0.011542           0.023085                    0.023085
# 3                0.015710           0.020946                    0.062838
# 4                0.017291           0.023055                    0.069164
# ..                    ...                ...                         ...
# 447              0.010646           0.042584                    0.014195
# 448              0.031452           0.125808                    0.041936
# 449              0.010113           1.516943                    0.010181
# 450              0.014012           0.018683                    0.056048
# 451              0.000753           0.006780                    0.000848
#
#     Composition
# 0       Li1 Ga3
# 1       Li2 Cu6
# 2       Li1 Ag1
# 3       Li3 Pd1
# 4       Li3 In1
# ..          ...
# 447     Li1 Tl3
# 448     Li1 Pm3
# 449   Li1 Mg149
# 450     Li3 Pt1
# 451      Li1 O8
#
# [452 rows x 10 columns]

# %% [markdown]
# ### Thougest part is to make the Feature functions data

# %%
props = pd.read_csv('../all_compounds/PubChemElements_all.csv')
polarisability = pd.read_csv('../elements_polarizability.csv')

props = props[['Symbol', 'AtomicMass','AtomicRadius','Electronegativity','IonizationEnergy','ElectronAffinity']]

# %%
all_props = []
cnt = 0
for items in li_d3s:
    # cnt+=1
    #get the path of each folder
    path = os.path.join("li_d3s", items)
    # print(items)
    
    #ignore .DS_Store
    if items == ".DS_Store":
        continue
    file = os.path.join(path, f'{items}.csv')
    struct_file = os.path.join(path, 'POSCAR')


    struct = Structure.from_file(struct_file)
    sites = struct.num_sites

    vol_site = struct.volume/sites
    # print(density)

    # print(struct.composition.elements[1])

    elem = struct.composition.elements[0] if(struct.composition.elements[1].symbol == 'Li')  else struct.composition.elements[1]

    print(elem)
    # print(elem.symbol == 'Ge')

    matched_row = props[props['Symbol'] == elem.symbol]
    elem_polarizability = polarisability[polarisability['Symbol'] == elem.symbol]

    space_group = struct.get_space_group_info()


    
    print(struct.composition.reduced_formula)
    # DiffPerLi = results_df[results_df['Symbol'] == elem.symbol]
    # matched_row.add('Polarizability', elem_polarizability['Polarizability'].values[0])
    matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
    matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
    matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
    # matched_row['TotalSites'] = results_df['Total Sites'][cnt]
    matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
    matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
    matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
    # matched_row['Diff per Li Sites'] = DiffPerLi['Diff per Li Sites'].values[0]
    matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
    matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
    matched_row['SpaceGroup'] = space_group[0]
    matched_row['SpaceGroupNumber'] = space_group[1]
    matched_row['Total Sites'] = sites

    matched_row["Reduced Formula"] = struct.composition.reduced_formula
    all_props.append(matched_row)

    cnt+=1

all_props_df = pd.concat(all_props, ignore_index=True)
# Out:
# Ga
# LiGa3
# Cu
# LiCu3
# Ag
# LiAg
# Pd
# Li3Pd
# In
# Li3In
# Pr
# LiPr3
# Mg
# LiMg
# Ce
# LiCe3
# Sb
# Li27Sb10
# Cd
# Li2Cd
# Al
# Li3Al2
# P
# Li3P
# Na
# NaLi3
# Al
# Li2Al
# S
# Li2S
# Mg
# LiMg3
# Tc
# Li3Tc
# Ca
# Li3Ca
# In
# LiIn3
# Si
# Li7Si2
# Rb
# Rb3Li
# K
# K3Li
# Pb
# Li10Pb3
# C
# Li3C
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# ...
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_li'] = results_df['Diff per Li Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['LiSites'] = results_df['Li Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_75758/1550152265.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula

# %%
all_props_df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Ga    69.72300         187.0               1.81             5.999
# 1       Cu    63.55000         140.0               1.90             7.726
# 2       Ag   107.86800         172.0               1.93             7.576
# 3       Pd   106.42000         202.0               2.20             8.337
# 4       In   114.81800         193.0               1.78             5.786
# ..     ...         ...           ...                ...               ...
# 447     Tl   204.38300         196.0               1.62             6.108
# 448     Pm   144.91276         236.0                NaN             5.550
# 449     Mg    24.30500         173.0               1.31             7.646
# 450     Pt   195.08000         209.0               2.28             9.000
# 451      O    15.99900         152.0               3.44            13.618
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_li  \
# 0               0.300           50.00          11.709881       46.839522
# 1               1.228           46.50          14.243751       56.975002
# 2               1.302           55.00          11.542257       23.084513
# 3               0.557           26.14          15.709607       20.946143
# 4               0.300           65.00          17.290921       23.054561
# ..                ...             ...                ...             ...
# 447             0.200           66.00          10.645902       42.583610
# 448               NaN          200.00          31.451888      125.807550
# 449               NaN           71.20          10.112955     1516.943228
# 450             2.128           48.00          14.011933       18.682577
# 451             1.461            5.30           0.753340        6.780058
#
#       LiSites  CounterIonSites  results_per_counter_ion  \
# 0    0.250000         0.750000                 0.015613
# 1    0.250000         0.750000                 0.018992
# 2    0.500000         0.500000                 0.023085
# 3    0.750000         0.250000                 0.062838
# 4    0.750000         0.250000                 0.069164
# ..        ...              ...                      ...
# 447  0.250000         0.750000                 0.014195
# 448  0.250000         0.750000                 0.041936
# 449  0.006667         0.993333                 0.010181
# 450  0.750000         0.250000                 0.056048
# 451  0.111111         0.888889                 0.000848
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 0                 0.000727  0.726735     I4/mmm               139
# 1                 0.001231  1.230899   P6_3/mmc               194
# 2                 0.000758  0.758077      Pm-3m               221
# 3                 0.001091  1.091082      Fm-3m               225
# 4                 0.000945  0.944589     I4/mmm               139
# ..                     ...       ...        ...               ...
# 447               0.000411  0.410720      Pm-3m               221
# 448               0.001007  1.007100      Pm-3m               221
# 449               0.000452  0.451801      P-6m2               187
# 450               0.000998  0.997600     I4/mmm               139
# 451               0.000060  0.060450       C2/m                12
#
#      Total Sites Reduced Formula
# 0              4           LiGa3
# 1              8           LiCu3
# 2              2            LiAg
# 3              4           Li3Pd
# 4              4           Li3In
# ..           ...             ...
# 447            4           LiTl3
# 448            4           LiPm3
# 449          150         LiMg149
# 450            4           Li3Pt
# 451            9            LiO8
#
# [452 rows x 18 columns]

# %%
all_props_df.to_csv('all_props_new.csv', index=False)

# %%
# show me some graphs to analyze NaN values

import matplotlib.pyplot as plt
import seaborn as sns

# Example DataFrame with NaN values (replace this with your actual DataFrame)
# For demonstration, we're creating a DataFrame with some random missing values.
np.random.seed(42)
data = {
    'A': np.random.choice([1, 2, np.nan], size=100),
    'B': np.random.choice([3, 4, np.nan], size=100),
    'C': np.random.choice([5, 6, np.nan], size=100),
    'D': np.random.choice([7, 8, np.nan], size=100)
}
df = pd.DataFrame(data)

# -------------------------------
# Plot 1: Heatmap of Missing Values
# -------------------------------
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Heatmap of Missing Values")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# -------------------------------
# Plot 2: Bar Chart of Missing Values per Column
# -------------------------------
missing_counts = df.isnull().sum().sort_values(ascending=False)
plt.figure(figsize=(8, 5))
missing_counts.plot(kind="bar", color='salmon')
plt.ylabel("Number of missing values")
plt.xlabel("Columns")
plt.title("Missing Values Count per Column")
plt.show()

# %%
all_props_df.fillna(0, inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(all_props_df.isnull(), cbar=False, cmap="viridis")
plt.title("Heatmap of Missing Values")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %%
all_props_df.to_csv('all_props.csv', index=False)
all_props_df = pd.read_csv('all_props.csv')

all_props_df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Ga    69.72300         187.0               1.81             5.999
# 1       Cu    63.55000         140.0               1.90             7.726
# 2       Ag   107.86800         172.0               1.93             7.576
# 3       Pd   106.42000         202.0               2.20             8.337
# 4       In   114.81800         193.0               1.78             5.786
# ..     ...         ...           ...                ...               ...
# 447     Tl   204.38300         196.0               1.62             6.108
# 448     Pm   144.91276         236.0               0.00             5.550
# 449     Mg    24.30500         173.0               1.31             7.646
# 450     Pt   195.08000         209.0               2.28             9.000
# 451      O    15.99900         152.0               3.44            13.618
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_li  \
# 0               0.300           50.00           0.011710        0.011710
# 1               1.228           46.50           0.014244        0.014244
# 2               1.302           55.00           0.011542        0.011542
# 3               0.557           26.14           0.015710        0.015710
# 4               0.300           65.00           0.017291        0.017291
# ..                ...             ...                ...             ...
# 447             0.200           66.00           0.010646        0.010646
# 448             0.000          200.00           0.031452        0.031452
# 449             0.000           71.20           0.010113        0.010113
# 450             2.128           48.00           0.014012        0.014012
# 451             1.461            5.30           0.000753        0.000753
#
#      LiSites  CounterIonSites  results_per_counter_ion
# 0        1.0              3.0                 0.011710
# 1        2.0              6.0                 0.014244
# 2        1.0              1.0                 0.011542
# 3        3.0              1.0                 0.015710
# 4        3.0              1.0                 0.017291
# ..       ...              ...                      ...
# 447      1.0              3.0                 0.010646
# 448      1.0              3.0                 0.031452
# 449      1.0            149.0                 0.010113
# 450      3.0              1.0                 0.014012
# 451      1.0              8.0                 0.000753
#
# [452 rows x 12 columns]
