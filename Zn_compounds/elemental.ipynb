# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('all_props_new.csv')

# %%
df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Ba      137.33         268.0               0.89             5.212
# 1       Ba      137.33         268.0               0.89             5.212
# 2       Ba      137.33         268.0               0.89             5.212
# 3       Ba      137.33         268.0               0.89             5.212
# 4       Ca       40.08         231.0               1.00             6.113
# ..     ...         ...           ...                ...               ...
# 159     Se       78.97         190.0               2.55             9.752
# 160      S       32.07         180.0               2.58            10.360
# 161     Te      127.60         206.0               2.10             9.010
# 162     Zr       91.22         186.0               1.33             6.634
# 163     Zr       91.22         186.0               1.33             6.634
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 0                 NaN           272.0           0.012687        0.038062
# 1                 NaN           272.0           0.008223        0.008855
# 2                 NaN           272.0           0.011320        0.016980
# 3                 NaN           272.0           0.009284        0.011140
# 4                 NaN           160.8           0.010972        0.029258
# ..                ...             ...                ...             ...
# 159             2.021            28.9           0.002714        0.005429
# 160             2.077            19.4           0.002662        0.005324
# 161             1.971            38.0           0.002715        0.005429
# 162             0.426           112.0           0.015521        0.023282
# 163             0.426           112.0           0.017877        0.035753
#
#      ZnSites  CounterIonSites  results_per_counter_ion SpaceGroup  \
# 0        1.0              1.0                 0.038062     I4/mmm
# 1       26.0             26.0                 0.008855      Fm-3c
# 2        4.0              4.0                 0.016980       C2/c
# 3       10.0             10.0                 0.011140       Cmcm
# 4        6.0              6.0                 0.029258     I4/mcm
# ..       ...              ...                      ...        ...
# 159      1.0              1.0                 0.005429      F-43m
# 160     28.0             28.0                 0.005324       P3m1
# 161      3.0              3.0                 0.005429      F-43m
# 162      4.0              4.0                 0.023282      Fd-3m
# 163      1.0              1.0                 0.035753      Pm-3m
#
#      SpaceGroupNumber  Total Sites Reduced Formula
# 0                 139            3           Ba2Zn
# 1                 226           28          BaZn13
# 2                  15            6           BaZn2
# 3                  63           12           BaZn5
# 4                 140           16          Ca5Zn3
# ..                ...          ...             ...
# 159               216            2            ZnSe
# 160               156           56             ZnS
# 161               216            6            ZnTe
# 162               227            6           ZrZn2
# 163               221            2            ZrZn
#
# [164 rows x 16 columns]

# %%
element = 'Cl'

# %%
grouped_df = df.groupby('Symbol')
oxy_group = pd.DataFrame()
for symbol, group in grouped_df:
    # print(f"Category: {symbol}")
    # print(group['Result'].max())
    # print(group['Result'].min())
    if symbol == element:
        # print(group['Result'])
        # print('---------------------')
        # print((group['Result'].max() - group['Result'].min())/group['Result'].mean() * 100)
        # print(group)
        oxy_group  = group
    # if(symbol == 'Al'):
    #     print(group)
    # print("\n")

oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 145     Cl       35.45         175.0               3.16            12.968
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 145             3.617            14.6           0.000845        0.002535
#
#      ZnSites  CounterIonSites  results_per_counter_ion SpaceGroup  \
# 145      2.0              4.0                 0.001268      I-42d
#
#      SpaceGroupNumber  Total Sites Reduced Formula
# 145               122            6           ZnCl2

# %%
res = pd.read_csv('analysis_results.csv')
res
# Out:
#     Symbol Structure  Total Sites  Zn Sites  Counter Ion Sites  Diff Energy  \
# 0       Ba   Ba2 Zn1            3       1.0                1.0     0.038062
# 1       Ba  Ba2 Zn26           28      26.0               26.0     0.230236
# 2       Ba   Ba2 Zn4            6       4.0                4.0     0.067920
# 3       Ba  Ba2 Zn10           12      10.0               10.0     0.111404
# 4       Ca  Ca10 Zn6           16       6.0                6.0     0.175547
# ..     ...       ...          ...       ...                ...          ...
# 159     Se   Zn1 Se1            2       1.0                1.0     0.005429
# 160      S  Zn28 S28           56      28.0               28.0     0.149080
# 161     Te   Zn3 Te3            6       3.0                3.0     0.016287
# 162     Zr   Zr2 Zn4            6       4.0                4.0     0.093127
# 163     Zr   Zr1 Zn1            2       1.0                1.0     0.035753
#
#      Diff per Total Sites  Diff per Zn Sites  Diff per Counter Ion Sites  \
# 0                0.012687           0.038062                    0.038062
# 1                0.008223           0.008855                    0.008855
# 2                0.011320           0.016980                    0.016980
# 3                0.009284           0.011140                    0.011140
# 4                0.010972           0.029258                    0.029258
# ..                    ...                ...                         ...
# 159              0.002714           0.005429                    0.005429
# 160              0.002662           0.005324                    0.005324
# 161              0.002715           0.005429                    0.005429
# 162              0.015521           0.023282                    0.023282
# 163              0.017877           0.035753                    0.035753
#
#     Composition
# 0       Ba2 Zn1
# 1      Ba2 Zn26
# 2       Ba2 Zn4
# 3      Ba2 Zn10
# 4      Ca10 Zn6
# ..          ...
# 159     Zn1 Se1
# 160    Zn28 S28
# 161     Zn3 Te3
# 162     Zr2 Zn4
# 163     Zr1 Zn1
#
# [164 rows x 10 columns]

# %%
res = res[res['Symbol'] == element]

res
# Out:
#    Symbol Structure  Total Sites  Zn Sites  Counter Ion Sites  Diff Energy  \
# 43     La  La2 Zn17           19      17.0               17.0     0.255115
# 44     La  La6 Zn44           50      44.0               44.0     0.690247
# 45     La  La2 Zn22           24      22.0               22.0     0.304328
# 46     La  La2 Zn26           28      26.0               26.0     0.352609
# 47     La   La2 Zn4            6       4.0                4.0     0.090355
# 48     La   La2 Zn8           10       8.0                8.0     0.133919
# 49     La   La1 Zn1            2       1.0                1.0     0.034603
#
#     Diff per Total Sites  Diff per Zn Sites  Diff per Counter Ion Sites  \
# 43              0.013427           0.015007                    0.015007
# 44              0.013805           0.015687                    0.015687
# 45              0.012680           0.013833                    0.013833
# 46              0.012593           0.013562                    0.013562
# 47              0.015059           0.022589                    0.022589
# 48              0.013392           0.016740                    0.016740
# 49              0.017301           0.034603                    0.034603
#
#    Composition
# 43    La2 Zn17
# 44    La6 Zn44
# 45    La2 Zn22
# 46    La2 Zn26
# 47     La2 Zn4
# 48     La2 Zn8
# 49     La1 Zn1

# %%
oxy_group
# Out:
#    Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 43     La    138.9055         240.0                1.1             5.577
# 44     La    138.9055         240.0                1.1             5.577
# 45     La    138.9055         240.0                1.1             5.577
# 46     La    138.9055         240.0                1.1             5.577
# 47     La    138.9055         240.0                1.1             5.577
# 48     La    138.9055         240.0                1.1             5.577
# 49     La    138.9055         240.0                1.1             5.577
#
#     ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 43               0.5           215.0           0.013427        0.015007
# 44               0.5           215.0           0.013805        0.015687
# 45               0.5           215.0           0.012680        0.013833
# 46               0.5           215.0           0.012593        0.013562
# 47               0.5           215.0           0.015059        0.022589
# 48               0.5           215.0           0.013392        0.016740
# 49               0.5           215.0           0.017301        0.034603
#
#     ZnSites  CounterIonSites  results_per_counter_ion SpaceGroup  \
# 43     17.0             17.0                 0.015007       R-3m
# 44     44.0             44.0                 0.015687       C2/c
# 45     22.0             22.0                 0.013833       C2/m
# 46     26.0             26.0                 0.013562      Fm-3c
# 47      4.0              4.0                 0.022589       Imma
# 48      8.0              8.0                 0.016740       Cmcm
# 49      1.0              1.0                 0.034603      Pm-3m
#
#     SpaceGroupNumber  Total Sites Reduced Formula
# 43               166           19         La2Zn17
# 44                15           50         La3Zn22
# 45                12           24          LaZn11
# 46               226           28          LaZn13
# 47                74            6           LaZn2
# 48                63           10           LaZn4
# 49               221            2            LaZn

# %%
merged_df = pd.merge(res, oxy_group, left_index=True, right_index=True)
# merged_df.sort_values(by='Result',inplace=True, ascending=False)
merged_df['SpaceGroup']

merged_df
# Out:
#    Symbol_x Structure  Total Sites_x  Zn Sites  Counter Ion Sites  \
# 43       La  La2 Zn17             19      17.0               17.0
# 44       La  La6 Zn44             50      44.0               44.0
# 45       La  La2 Zn22             24      22.0               22.0
# 46       La  La2 Zn26             28      26.0               26.0
# 47       La   La2 Zn4              6       4.0                4.0
# 48       La   La2 Zn8             10       8.0                8.0
# 49       La   La1 Zn1              2       1.0                1.0
#
#     Diff Energy  Diff per Total Sites  Diff per Zn Sites  \
# 43     0.255115              0.013427           0.015007
# 44     0.690247              0.013805           0.015687
# 45     0.304328              0.012680           0.013833
# 46     0.352609              0.012593           0.013562
# 47     0.090355              0.015059           0.022589
# 48     0.133919              0.013392           0.016740
# 49     0.034603              0.017301           0.034603
#
#     Diff per Counter Ion Sites Composition  ... Polarizability  \
# 43                    0.015007    La2 Zn17  ...          215.0
# 44                    0.015687    La6 Zn44  ...          215.0
# 45                    0.013833    La2 Zn22  ...          215.0
# 46                    0.013562    La2 Zn26  ...          215.0
# 47                    0.022589     La2 Zn4  ...          215.0
# 48                    0.016740     La2 Zn8  ...          215.0
# 49                    0.034603     La1 Zn1  ...          215.0
#
#     results_per_total  results_per_zn  ZnSites  CounterIonSites  \
# 43           0.013427        0.015007     17.0             17.0
# 44           0.013805        0.015687     44.0             44.0
# 45           0.012680        0.013833     22.0             22.0
# 46           0.012593        0.013562     26.0             26.0
# 47           0.015059        0.022589      4.0              4.0
# 48           0.013392        0.016740      8.0              8.0
# 49           0.017301        0.034603      1.0              1.0
#
#     results_per_counter_ion  SpaceGroup  SpaceGroupNumber  Total Sites_y  \
# 43                 0.015007        R-3m               166             19
# 44                 0.015687        C2/c                15             50
# 45                 0.013833        C2/m                12             24
# 46                 0.013562       Fm-3c               226             28
# 47                 0.022589        Imma                74              6
# 48                 0.016740        Cmcm                63             10
# 49                 0.034603       Pm-3m               221              2
#
#     Reduced Formula
# 43          La2Zn17
# 44          La3Zn22
# 45           LaZn11
# 46           LaZn13
# 47            LaZn2
# 48            LaZn4
# 49             LaZn
#
# [7 rows x 26 columns]

# %%
merged_df.rename(columns={"results_per_total": "Result_1"}, inplace=True)
merged_df['Total Sites_x']
# Out:
# 43    19
# 44    50
# 45    24
# 46    28
# 47     6
# 48    10
# 49     2
# Name: Total Sites_x, dtype: int64

# %%
merged_df.sort_values(by='Result_1',inplace=True, ascending=False)

# %%
symbol = merged_df['Symbol_x'].values[0]
symbol
# Out:
# 'La'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create combined x-axis label
merged_df['Structure_SG'] = merged_df['Reduced Formula'] + ' | ' + merged_df['SpaceGroup'].astype(str)

# Set data
x_labels = merged_df['Structure_SG']
values = merged_df['Result_1']

# Create figure
plt.figure(figsize=(10, 6))

# Create bar plot
x = np.arange(len(x_labels))  # numeric x-axis positions
plt.bar(x, values, width=0.6, label='Result_1')

# X-axis setup
plt.xticks(x, x_labels, rotation=60, ha='right')
plt.xlabel('Structure | SpaceGroup')
plt.ylabel('Value')
# plt.title('Grouped Bar Plot of Result_1 by Structure and SpaceGroup')
plt.legend(title='Metric')
plt.tight_layout()

# Save or show
plt.savefig(f'chemical_space/li_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()
