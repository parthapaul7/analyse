# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('analysis_results.csv')

# %%
df.sort_values(by='Diff per Li Sites', ascending=False, inplace=True)
df
# Out:
#    Structure  Total Sites  Li Sites  Diff Energy  Diff per Total Sites  \
# 55   Li3 Mg3            6       3.0     0.103098              0.017183
# 38   Li1 Pa1            2       1.0     0.034295              0.017148
# 43   Li1 Rh1            2       1.0     0.033398              0.016699
# 1    Li3 Mg3            6       3.0     0.099944              0.016657
# 9    Li2 Mg2            4       2.0     0.066364              0.016591
# ..       ...          ...       ...          ...                   ...
# 16    Li2 B2            4       2.0     0.005657              0.001414
# 23   Li8 Ge8           16       8.0     0.021852              0.001366
# 0    Li6 Ge6           12       6.0     0.016010              0.001334
# 3    Li2 Si2            4       2.0     0.004792              0.001198
# 2     Li2 B2            4       2.0     0.004352              0.001088
#
#     Diff per Li Sites Composition
# 55           0.034366     Li3 Mg3
# 38           0.034295     Li1 Pa1
# 43           0.033398     Li1 Rh1
# 1            0.033315     Li3 Mg3
# 9            0.033182     Li2 Mg2
# ..                ...         ...
# 16           0.002828      Li2 B2
# 23           0.002731     Li8 Ge8
# 0            0.002668     Li6 Ge6
# 3            0.002396     Li2 Si2
# 2            0.002176      Li2 B2
#
# [72 rows x 7 columns]

# %%
# plot strucure as x asis and diff per Li sites as y axis
plt.figure(figsize=(10, 5))
# sns.set(style="whitegrid")
sns.barplot(x='Structure', y='Diff per Li Sites', data=df, palette="Blues_d")
plt.xticks(rotation=90)
plt.xlabel('Structure')
plt.ylabel('Diff per Li Sites')
plt.title('Diff per Li Sites for Different Structures')
plt.tight_layout()
plt.savefig('diff_per_li_sites.png', dpi=300)
plt.show()
# Out:
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_31249/2873554367.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Structure', y='Diff per Li Sites', data=df, palette="Blues_d")
