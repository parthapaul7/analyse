# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
df = pd.read_csv('analysis_results.csv')

df['Index'] = df.groupby('Structure').cumcount().astype(str)

df['Index'] = df['Structure'] + '_' + df['Index']

# %%
df_sorted = df.sort_values(by='Diff per Li Sites', ascending=True, ignore_index=True)
df_sorted
# Out:
#    Structure  Total Sites  Li Sites  Diff Energy  Diff per Total Sites  \
# 0     Li2 B2            4       2.0     0.004352              0.001088
# 1    Li2 Si2            4       2.0     0.004792              0.001198
# 2    Li6 Ge6           12       6.0     0.016010              0.001334
# 3    Li8 Ge8           16       8.0     0.021852              0.001366
# 4     Li2 B2            4       2.0     0.005657              0.001414
# ..       ...          ...       ...          ...                   ...
# 67   Li2 Mg2            4       2.0     0.066364              0.016591
# 68   Li3 Mg3            6       3.0     0.099944              0.016657
# 69   Li1 Rh1            2       1.0     0.033398              0.016699
# 70   Li1 Pa1            2       1.0     0.034295              0.017148
# 71   Li3 Mg3            6       3.0     0.103098              0.017183
#
#     Diff per Li Sites Composition      Index
# 0            0.002176      Li2 B2   Li2 B2_0
# 1            0.002396     Li2 Si2  Li2 Si2_0
# 2            0.002668     Li6 Ge6  Li6 Ge6_0
# 3            0.002731     Li8 Ge8  Li8 Ge8_0
# 4            0.002828      Li2 B2   Li2 B2_1
# ..                ...         ...        ...
# 67           0.033182     Li2 Mg2  Li2 Mg2_0
# 68           0.033315     Li3 Mg3  Li3 Mg3_0
# 69           0.033398     Li1 Rh1  Li1 Rh1_0
# 70           0.034295     Li1 Pa1  Li1 Pa1_0
# 71           0.034366     Li3 Mg3  Li3 Mg3_2
#
# [72 rows x 8 columns]

# %%
# plot strucure as x asis and diff per Li sites as y axis
plt.figure(figsize=(15, 5))
# sns.set(style="whitegrid")
sns.barplot(x='Index', y='Diff per Total Sites', data=df_sorted, palette="Blues_d",  errorbar=('ci', 0),  order=df_sorted['Index'])
plt.xticks(rotation=90)
plt.xlabel('Structure')
plt.ylabel('Diff per Li Sites')
plt.title('Diff per Li Sites for Different Structures')
plt.tight_layout()
plt.savefig('diff_per_li_sites.png', dpi=300)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13688\1827428992.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Index', y='Diff per Total Sites', data=df_sorted, palette="Blues_d",  errorbar=('ci', 0),  order=df_sorted['Index'])
