# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('all_props_new.csv')

# %%
df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Ba    137.3300         268.0               0.89             5.212
# 1       Ba    137.3300         268.0               0.89             5.212
# 2       Ba    137.3300         268.0               0.89             5.212
# 3        K     39.0983         275.0               0.82             4.341
# 4        K     39.0983         275.0               0.82             4.341
# ..     ...         ...           ...                ...               ...
# 447     Rb     85.4680         303.0               0.82             4.177
# 448     Sr     87.6200         249.0               0.95             5.695
# 449     Sr     87.6200         249.0               0.95             5.695
# 450     Sr     87.6200         249.0               0.95             5.695
# 451     Sr     87.6200         249.0               0.95             5.695
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_li  \
# 0                 NaN           272.0          18.816124       26.941269
# 1                 NaN           272.0          15.293690       61.174760
# 2                 NaN           272.0          18.343399       22.929249
# 3               0.501           289.7           1.991284        7.965135
# 4               0.501           289.7           1.925716        7.702865
# ..                ...             ...                ...             ...
# 447             0.468           319.8           1.854994        7.419975
# 448               NaN           197.2          16.745279       41.863197
# 449               NaN           197.2          18.141579       72.566315
# 450               NaN           197.2          17.732723       70.930890
# 451               NaN           197.2          19.335571       24.379633
#
#       LiSites  CounterIonSites  results_per_counter_ion  \
# 0    0.698413         0.698413                 0.026941
# 1    0.250000         0.250000                 0.061175
# 2    0.800000         0.800000                 0.022929
# 3    0.250000         0.250000                 0.007965
# 4    0.250000         0.250000                 0.007703
# ..        ...              ...                      ...
# 447  0.250000         0.250000                 0.007420
# 448  0.400000         0.400000                 0.041863
# 449  0.250000         0.250000                 0.072566
# 450  0.250000         0.250000                 0.070931
# 451  0.793103         0.793103                 0.024380
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 0                 0.000559  0.559487      I-42d               122
# 1                 0.000279  0.278575     I4/mmm               139
# 2                 0.000606  0.606374   P6_3/mmc               194
# 3                 0.000034  0.033661      Pm-3m               221
# 4                 0.000034  0.033833      Fm-3m               225
# ..                     ...       ...        ...               ...
# 447               0.000027  0.026635     I4/mmm               139
# 448               0.000397  0.397018   P4_2/mnm               136
# 449               0.000386  0.385945   P6_3/mmc               194
# 450               0.000371  0.371091     I4/mmm               139
# 451               0.000686  0.685507      Fm-3m               225
#
#      Total Sites Reduced Formula
# 0            126        Ba19Li44
# 1              4           Ba3Li
# 2             30           BaLi4
# 3              4            K3Li
# 4              4            K3Li
# ..           ...             ...
# 447            4           Rb3Li
# 448           20          Sr3Li2
# 449            8           Sr3Li
# 450            4           Sr3Li
# 451           29         Sr6Li23
#
# [452 rows x 18 columns]

# %%
element = 'Si'

# %%
grouped_df = df.groupby('Symbol')
oxy_group = pd.DataFrame()
for symbol, group in grouped_df:
    # print(f"Category: {symbol}")
    # print(group['Result'].max())
    # print(group['Result'].min())
    if symbol == element:
        # print(group['Result'])
        # print('---------------------')
        # print((group['Result'].max() - group['Result'].min())/group['Result'].mean() * 100)
        # print(group)
        oxy_group  = group
    # if(symbol == 'Al'):
    #     print(group)
    # print("\n")

oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 11      Si      28.085         210.0                1.9             8.152
# 13      Si      28.085         210.0                1.9             8.152
# 18      Si      28.085         210.0                1.9             8.152
# 21      Si      28.085         210.0                1.9             8.152
# 24      Si      28.085         210.0                1.9             8.152
# 66      Si      28.085         210.0                1.9             8.152
# 198     Si      28.085         210.0                1.9             8.152
# 199     Si      28.085         210.0                1.9             8.152
# 404     Si      28.085         210.0                1.9             8.152
# 405     Si      28.085         210.0                1.9             8.152
# 406     Si      28.085         210.0                1.9             8.152
# 407     Si      28.085         210.0                1.9             8.152
# 408     Si      28.085         210.0                1.9             8.152
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_li  \
# 11              1.385            37.3           0.836953        1.325175
# 13              1.385            37.3          12.034944       15.738003
# 18              1.385            37.3          13.847690       17.540407
# 21              1.385            37.3          13.140352       16.269007
# 24              1.385            37.3          13.518213       16.590534
# 66              1.385            37.3           0.676246        1.014369
# 198             1.385            37.3          10.837360       13.933748
# 199             1.385            37.3           0.592535        0.846479
# 404             1.385            37.3           1.875387        7.501548
# 405             1.385            37.3           1.885589        7.542355
# 406             1.385            37.3           1.197946        2.395892
# 407             1.385            37.3           0.570098        1.140197
# 408             1.385            37.3           7.509397       15.018794
#
#       LiSites  CounterIonSites  results_per_counter_ion  \
# 11   0.631579         0.368421                 0.002272
# 13   0.764706         0.235294                 0.051149
# 18   0.789474         0.210526                 0.065777
# 21   0.807692         0.192308                 0.068330
# 24   0.814815         0.185185                 0.072998
# 66   0.666667         0.333333                 0.002029
# 198  0.777778         0.222222                 0.048768
# 199  0.700000         0.300000                 0.001975
# 404  0.250000         0.750000                 0.002501
# 405  0.250000         0.750000                 0.002514
# 406  0.500000         0.500000                 0.002396
# 407  0.500000         0.500000                 0.001140
# 408  0.500000         0.500000                 0.015019
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 11                0.000053  0.053095       Pnma                62
# 13                0.000781  0.781478       Pbam                55
# 18                0.000895  0.894723      I-43d               220
# 21                0.000859  0.858813      F-43m               216
# 24                0.000901  0.900996      F-43m               216
# 66                0.000041  0.040525       R-3m               166
# 198               0.000736  0.735853       Pbam                55
# 199               0.000041  0.040605         C2                 5
# 404               0.000133  0.132584     I4/mmm               139
# 405               0.000129  0.128936   P6_3/mmc               194
# 406               0.000080  0.079604      Fd-3m               227
# 407               0.000023  0.023338     I4_1/a                88
# 408               0.000485  0.484640        P-1                 2
#
#      Total Sites Reduced Formula
# 11           152         Li12Si7
# 13            34         Li13Si4
# 18            38         Li15Si4
# 21           104         Li21Si5
# 24           108         Li22Si5
# 66             6           Li2Si
# 198           36          Li7Si2
# 199           60          Li7Si3
# 404            4           LiSi3
# 405            8           LiSi3
# 406            4            LiSi
# 407           16            LiSi
# 408           16            LiSi

# %%
res = pd.read_csv('analysis_results.csv')

# %%
res = res[res['Symbol'] == element]

res
# Out:
#     Symbol  Structure  Total Sites  Li Sites  Counter Ion Sites  Diff Energy  \
# 11      Si  Li96 Si56          152      96.0               56.0     0.127217
# 13      Si   Li26 Si8           34      26.0                8.0     0.409188
# 18      Si   Li30 Si8           38      30.0                8.0     0.526212
# 21      Si  Li84 Si20          104      84.0               20.0     1.366597
# 24      Si  Li88 Si20          108      88.0               20.0     1.459967
# 66      Si    Li4 Si2            6       4.0                2.0     0.004057
# 198     Si   Li28 Si8           36      28.0                8.0     0.390145
# 199     Si  Li42 Si18           60      42.0               18.0     0.035552
# 404     Si    Li1 Si3            4       1.0                3.0     0.007502
# 405     Si    Li2 Si6            8       2.0                6.0     0.015085
# 406     Si    Li2 Si2            4       2.0                2.0     0.004792
# 407     Si    Li8 Si8           16       8.0                8.0     0.009122
# 408     Si    Li8 Si8           16       8.0                8.0     0.120150
#
#      Diff per Total Sites  Diff per Li Sites  Diff per Counter Ion Sites  \
# 11               0.000837           0.001325                    0.002272
# 13               0.012035           0.015738                    0.051149
# 18               0.013848           0.017540                    0.065777
# 21               0.013140           0.016269                    0.068330
# 24               0.013518           0.016591                    0.072998
# 66               0.000676           0.001014                    0.002029
# 198              0.010837           0.013934                    0.048768
# 199              0.000593           0.000846                    0.001975
# 404              0.001875           0.007502                    0.002501
# 405              0.001886           0.007542                    0.002514
# 406              0.001198           0.002396                    0.002396
# 407              0.000570           0.001140                    0.001140
# 408              0.007509           0.015019                    0.015019
#
#     Composition
# 11    Li96 Si56
# 13     Li26 Si8
# 18     Li30 Si8
# 21    Li84 Si20
# 24    Li88 Si20
# 66      Li4 Si2
# 198    Li28 Si8
# 199   Li42 Si18
# 404     Li1 Si3
# 405     Li2 Si6
# 406     Li2 Si2
# 407     Li8 Si8
# 408     Li8 Si8

# %%
oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 11      Si      28.085         210.0                1.9             8.152
# 13      Si      28.085         210.0                1.9             8.152
# 18      Si      28.085         210.0                1.9             8.152
# 21      Si      28.085         210.0                1.9             8.152
# 24      Si      28.085         210.0                1.9             8.152
# 66      Si      28.085         210.0                1.9             8.152
# 198     Si      28.085         210.0                1.9             8.152
# 199     Si      28.085         210.0                1.9             8.152
# 404     Si      28.085         210.0                1.9             8.152
# 405     Si      28.085         210.0                1.9             8.152
# 406     Si      28.085         210.0                1.9             8.152
# 407     Si      28.085         210.0                1.9             8.152
# 408     Si      28.085         210.0                1.9             8.152
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_li  \
# 11              1.385            37.3           0.836953        1.325175
# 13              1.385            37.3          12.034944       15.738003
# 18              1.385            37.3          13.847690       17.540407
# 21              1.385            37.3          13.140352       16.269007
# 24              1.385            37.3          13.518213       16.590534
# 66              1.385            37.3           0.676246        1.014369
# 198             1.385            37.3          10.837360       13.933748
# 199             1.385            37.3           0.592535        0.846479
# 404             1.385            37.3           1.875387        7.501548
# 405             1.385            37.3           1.885589        7.542355
# 406             1.385            37.3           1.197946        2.395892
# 407             1.385            37.3           0.570098        1.140197
# 408             1.385            37.3           7.509397       15.018794
#
#       LiSites  CounterIonSites  results_per_counter_ion  \
# 11   0.631579         0.368421                 0.002272
# 13   0.764706         0.235294                 0.051149
# 18   0.789474         0.210526                 0.065777
# 21   0.807692         0.192308                 0.068330
# 24   0.814815         0.185185                 0.072998
# 66   0.666667         0.333333                 0.002029
# 198  0.777778         0.222222                 0.048768
# 199  0.700000         0.300000                 0.001975
# 404  0.250000         0.750000                 0.002501
# 405  0.250000         0.750000                 0.002514
# 406  0.500000         0.500000                 0.002396
# 407  0.500000         0.500000                 0.001140
# 408  0.500000         0.500000                 0.015019
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 11                0.000053  0.053095       Pnma                62
# 13                0.000781  0.781478       Pbam                55
# 18                0.000895  0.894723      I-43d               220
# 21                0.000859  0.858813      F-43m               216
# 24                0.000901  0.900996      F-43m               216
# 66                0.000041  0.040525       R-3m               166
# 198               0.000736  0.735853       Pbam                55
# 199               0.000041  0.040605         C2                 5
# 404               0.000133  0.132584     I4/mmm               139
# 405               0.000129  0.128936   P6_3/mmc               194
# 406               0.000080  0.079604      Fd-3m               227
# 407               0.000023  0.023338     I4_1/a                88
# 408               0.000485  0.484640        P-1                 2
#
#      Total Sites Reduced Formula
# 11           152         Li12Si7
# 13            34         Li13Si4
# 18            38         Li15Si4
# 21           104         Li21Si5
# 24           108         Li22Si5
# 66             6           Li2Si
# 198           36          Li7Si2
# 199           60          Li7Si3
# 404            4           LiSi3
# 405            8           LiSi3
# 406            4            LiSi
# 407           16            LiSi
# 408           16            LiSi

# %%
merged_df = pd.merge(res, oxy_group, left_index=True, right_index=True)
# merged_df.sort_values(by='Result',inplace=True, ascending=False)
merged_df['SpaceGroup']

merged_df['Counter Ion Sites']
# Out:
# 11     56.0
# 13      8.0
# 18      8.0
# 21     20.0
# 24     20.0
# 66      2.0
# 198     8.0
# 199    18.0
# 404     3.0
# 405     6.0
# 406     2.0
# 407     8.0
# 408     8.0
# Name: Counter Ion Sites, dtype: float64

# %%
merged_df.rename(columns={"results_per_total": "Result_1"}, inplace=True)
merged_df['Total Sites_x']
# Out:
# 11     152
# 13      34
# 18      38
# 21     104
# 24     108
# 66       6
# 198     36
# 199     60
# 404      4
# 405      8
# 406      4
# 407     16
# 408     16
# Name: Total Sites_x, dtype: int64

# %%
# merged_df.sort_values(,inplace=True, ascending=False)

# %%
symbol = merged_df['Symbol_x'].values[0]
symbol
# Out:
# 'Si'

# %%
full_li = merged_df['Li Sites']
merged_df['Anion Site'] = (merged_df['Counter Ion Sites'] / full_li).round(2)

merged_df.sort_values(by=['Anion Site','Result_1'],inplace=True, ascending=[True,False])
merged_df['Structure_SG'] = "Li-" + symbol+(merged_df['Counter Ion Sites'] / full_li).round(2).astype(str)

# %%
merged_df
# Out:
#     Symbol_x  Structure  Total Sites_x  Li Sites  Counter Ion Sites  \
# 24        Si  Li88 Si20            108      88.0               20.0
# 21        Si  Li84 Si20            104      84.0               20.0
# 18        Si   Li30 Si8             38      30.0                8.0
# 198       Si   Li28 Si8             36      28.0                8.0
# 13        Si   Li26 Si8             34      26.0                8.0
# 199       Si  Li42 Si18             60      42.0               18.0
# 66        Si    Li4 Si2              6       4.0                2.0
# 11        Si  Li96 Si56            152      96.0               56.0
# 408       Si    Li8 Si8             16       8.0                8.0
# 406       Si    Li2 Si2              4       2.0                2.0
# 407       Si    Li8 Si8             16       8.0                8.0
# 405       Si    Li2 Si6              8       2.0                6.0
# 404       Si    Li1 Si3              4       1.0                3.0
#
#      Diff Energy  Diff per Total Sites  Diff per Li Sites  \
# 24      1.459967              0.013518           0.016591
# 21      1.366597              0.013140           0.016269
# 18      0.526212              0.013848           0.017540
# 198     0.390145              0.010837           0.013934
# 13      0.409188              0.012035           0.015738
# 199     0.035552              0.000593           0.000846
# 66      0.004057              0.000676           0.001014
# 11      0.127217              0.000837           0.001325
# 408     0.120150              0.007509           0.015019
# 406     0.004792              0.001198           0.002396
# 407     0.009122              0.000570           0.001140
# 405     0.015085              0.001886           0.007542
# 404     0.007502              0.001875           0.007502
#
#      Diff per Counter Ion Sites Composition  ... CounterIonSites  \
# 24                     0.072998   Li88 Si20  ...        0.185185
# 21                     0.068330   Li84 Si20  ...        0.192308
# 18                     0.065777    Li30 Si8  ...        0.210526
# 198                    0.048768    Li28 Si8  ...        0.222222
# 13                     0.051149    Li26 Si8  ...        0.235294
# 199                    0.001975   Li42 Si18  ...        0.300000
# 66                     0.002029     Li4 Si2  ...        0.333333
# 11                     0.002272   Li96 Si56  ...        0.368421
# 408                    0.015019     Li8 Si8  ...        0.500000
# 406                    0.002396     Li2 Si2  ...        0.500000
# 407                    0.001140     Li8 Si8  ...        0.500000
# 405                    0.002514     Li2 Si6  ...        0.750000
# 404                    0.002501     Li1 Si3  ...        0.750000
#
#      results_per_counter_ion  res_per_volm_per_site    Result  SpaceGroup  \
# 24                  0.072998               0.000901  0.900996       F-43m
# 21                  0.068330               0.000859  0.858813       F-43m
# 18                  0.065777               0.000895  0.894723       I-43d
# 198                 0.048768               0.000736  0.735853        Pbam
# 13                  0.051149               0.000781  0.781478        Pbam
# 199                 0.001975               0.000041  0.040605          C2
# 66                  0.002029               0.000041  0.040525        R-3m
# 11                  0.002272               0.000053  0.053095        Pnma
# 408                 0.015019               0.000485  0.484640         P-1
# 406                 0.002396               0.000080  0.079604       Fd-3m
# 407                 0.001140               0.000023  0.023338      I4_1/a
# 405                 0.002514               0.000129  0.128936    P6_3/mmc
# 404                 0.002501               0.000133  0.132584      I4/mmm
#
#      SpaceGroupNumber  Total Sites_y  Reduced Formula  Anion Site  \
# 24                216            108          Li22Si5        0.23
# 21                216            104          Li21Si5        0.24
# 18                220             38          Li15Si4        0.27
# 198                55             36           Li7Si2        0.29
# 13                 55             34          Li13Si4        0.31
# 199                 5             60           Li7Si3        0.43
# 66                166              6            Li2Si        0.50
# 11                 62            152          Li12Si7        0.58
# 408                 2             16             LiSi        1.00
# 406               227              4             LiSi        1.00
# 407                88             16             LiSi        1.00
# 405               194              8            LiSi3        3.00
# 404               139              4            LiSi3        3.00
#
#      Structure_SG
# 24      Li-Si0.23
# 21      Li-Si0.24
# 18      Li-Si0.27
# 198     Li-Si0.29
# 13      Li-Si0.31
# 199     Li-Si0.43
# 66       Li-Si0.5
# 11      Li-Si0.58
# 408      Li-Si1.0
# 406      Li-Si1.0
# 407      Li-Si1.0
# 405      Li-Si3.0
# 404      Li-Si3.0
#
# [13 rows x 30 columns]

# %%
merged_df.to_csv(f'chemical_space/Li_{symbol}.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- after you have merged_df ready ---

# 1. Build a display label with subscripted CN
def make_disp_label(sg):
    # sg is like "Li-C0.33" or "K-C1.0"
    metal, cn_str = sg.split(f'-{element}')       # ["Li", "0.33"]
    # metal is "Li" or "K"; cn_str is "0.33", "1.0", etc.
    return rf"$\mathrm{{{metal}{element}}}_{{{cn_str}}}$"

merged_df['DispLabel'] = merged_df['Structure_SG'].apply(make_disp_label)

# 2. Plot
x = np.arange(len(merged_df))
values = merged_df['Result_1']
labels = merged_df['DispLabel']

plt.figure(figsize=(10, 6))
plt.bar(x, values, width=0.6, color='teal')

# 3. Use the LaTeX labels
plt.xticks(x, labels, rotation=60, ha='right', fontsize=16)
plt.yticks(fontsize=12)
plt.ylabel('Energy (mEh)', fontsize=12)

plt.tight_layout()
plt.savefig(f'chemical_space/li_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()
